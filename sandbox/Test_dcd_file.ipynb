# %% [markdown]
# # Test dcd file

# %%
import molsysmt as msm

# %%
molsys = msm.demo['chicken villin HP35']['traj_explicit_solvent.dcd']

# %%
molsys = msm.convert(molsys, to_form='mdtraj.DCDTrajectoryFile')

# %%
iterator = msm.Iterator(molsys, coordinates=True)

# %%
for coordinates in iterator:
    print(coordinates)
# Out:
# [[[[1.460800051689148 3.0943806171417236 -0.4795481860637665]   [1.5369267463684082 2.9996814727783203 -0.5129171013832092]   [1.5312848091125488 3.193472385406494 -0.38785505294799805]   ...   [1.306594967842102 0.8385721445083618 0.007493437267839909]   [0.3556663691997528 1.3147265911102295 1.1360278129577637]   [3.153200626373291 1.5036805868148804 0.7466792464256287]]]] nanometer
# [[[[4.216921329498291 -0.898603081703186 -0.6698121428489685]   [4.2895636558532715 -0.9465029835700989 -0.764518678188324]   [4.279328346252441 -0.7998849153518677 -0.5750736594200134]   ...   [0.18192946910858154 2.7150938510894775 3.1154725551605225]   [1.2784401178359985 0.21426652371883392 1.9611190557479858]   [3.7196011543273926 2.171841621398926 1.0653713941574097]]]] nanometer
# ...
