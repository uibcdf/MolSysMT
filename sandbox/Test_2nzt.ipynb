# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # There we go!

# %%
import molsysmt as msm

# %%
#file = '/home/diego/Ixtlilton/hot_projects/hexii/AF-P52789-F1-model_v4.pdb'
#file = '/home/diego/Ixtlilton/hot_projects/hexii/em.gro'
file = '/home/diego/repos@uibcdf/MolSysMT/molsysmt/data/gro/gmx_coords.gro'

# %%
# %%time
molsys = msm.convert(file)
# Out:
# CPU times: user 448 ms, sys: 89.2 ms, total: 537 ms
# Wall time: 559 ms

# %%
molsys.structures.coordinates
# Out:
# array([[[1.73 , 2.378, 2.451],
#         [1.666, 2.304, 2.472],
#         [1.803, 2.384, 2.521],
#         ...,
#         [0.291, 1.062, 2.906],
#         [0.779, 0.398, 1.944],
#         [1.932, 3.168, 1.543]]]) <Unit('nanometer')>

# %%
# %%time
bonds = msm.build.get_missing_bonds(molsys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <timed exec>:1
#
# File ~/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py:122, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     120     return func(all_args['self'], **final_args)
#     121 else:
# --> 122     return func(**final_args)
#
# File ~/repos@uibcdf/MolSysMT/molsysmt/build/get_missing_bonds.py:82, in get_missing_bonds(molecular_system, threshold, selection, structure_indices, syntax, engine, with_templates, skip_digestion)
#      80     aux_bonds = _bonds_in_water(atom_indices, atom_names, atom_types)
#      81     bonds_templates += aux_bonds
# ---> 82     mask[atom_indices]=False
#      83 elif group_type=='ion':
#      84     aux_bonds = _bonds_in_ion(atom_indices, atom_names, atom_types)
#
# NameError: name 'mask' is not defined

# %%
len(bonds)

# %%
msm.get(molsys, n_waters=True)

# %%
136392*2

# %%
molsys.topology.groups.group_name.tolist()
