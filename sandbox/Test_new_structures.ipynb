# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Test new structures

# %%
import molsysmt as msm

# %%
molsys = msm.build.build_peptide('AceProNme', to_form='molsysmt.MolSys')

# %%
molsys.topology.bonds
# Out:
#     atom1_index  atom2_index order  type
# 0             0            1  <NA>  <NA>
# 1             1            2  <NA>  <NA>
# 2             1            3  <NA>  <NA>
# 3             1            4  <NA>  <NA>
# 4             4            5  <NA>  <NA>
# 5             4            6  <NA>  <NA>
# 6             6            7  <NA>  <NA>
# 7             6           16  <NA>  <NA>
# 8             7            8  <NA>  <NA>
# 9             7            9  <NA>  <NA>
# 10            7           10  <NA>  <NA>
# 11           10           11  <NA>  <NA>
# 12           10           12  <NA>  <NA>
# 13           10           13  <NA>  <NA>
# 14           13           14  <NA>  <NA>
# 15           13           15  <NA>  <NA>
# 16           13           16  <NA>  <NA>
# 17           16           17  <NA>  <NA>
# 18           16           18  <NA>  <NA>
# 19           18           19  <NA>  <NA>
# 20           18           20  <NA>  <NA>
# 21           20           21  <NA>  <NA>
# 22           20           22  <NA>  <NA>
# 23           22           23  <NA>  <NA>
# 24           22           24  <NA>  <NA>
# 25           22           25  <NA>  <NA>

# %%
molsys.topology.chains['chain_type'].to_numpy(dtype=str, na_value=np.nan)
# Out:
# array(['nan'], dtype='<U3')

# %%
msm.convert(molsys, to_form='proline_dipeptide.h5msm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 msm.convert(molsys, to_form='proline_dipeptide.h5msm')
#
# File ~/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py:119, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     117     return func(all_args['self'], **final_args)
#     118 else:
# --> 119     return func(**final_args)
#
# File ~/repos@uibcdf/MolSysMT/molsysmt/basic/convert.py:516, in convert(molecular_system, to_form, selection, structure_indices, syntax, verbose, **kwargs)
#     512 # If one to one
#     514 if not isinstance(from_form, (list, tuple)):
# --> 516     output = _convert_one_to_one(molecular_system, to_form=to_form, selection=selection, structure_indices=structure_indices,
#     517             syntax=syntax, verbose=verbose, **kwargs)
#     520 # If multiple to one
#     521
#     522 else:
#     523
#     524     # conversions in private shortcuts
#     525     if tuple(sorted(from_form)) in _multiple_conversion_shortcuts:
#
# File ~/repos@uibcdf/MolSysMT/molsysmt/basic/convert.py:80, in _convert_one_to_one(molecular_system, to_form, selection, structure_indices, syntax, verbose, **kwargs)
#      77         if len(missing_arguments)>0:
#      78             raise NotCompatibleConversionError(from_form, to_form, missing_arguments)
# ---> 80     output = function(molecular_system, **conversion_arguments, **kwargs)
#      82 elif ('molsysmt.MolSys' in _dict_modules[from_form]._convert_to) and (to_form in _dict_modules['molsysmt.MolSys']._convert_to):
#      84     output = _convert_one_to_one(molecular_system, to_form='molsysmt.MolSys', selection=selection,
#      85             structure_indices=structure_indices, syntax=syntax, **kwargs)
#
# File ~/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py:119, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     117     return func(all_args['self'], **final_args)
#     118 else:
# --> 119     return func(**final_args)
#
# File ~/repos@uibcdf/MolSysMT/molsysmt/form/molsysmt_MolSys/to_file_h5msm.py:15, in to_file_h5msm(item, atom_indices, structure_indices, output_filename, compression, compression_opts, int_precision, float_precision)
#       9 from ..molsysmt_Structures.to_file_h5msm import _add_structures_to_h5msm
#      11 handler = H5MSMFileHandler(output_filename, io_mode='w', compression=compression,
#      12         compression_opts=compression_opts, int_precision=int_precision,
#      13         float_precision=float_precision, closed=False)
# ---> 15 _add_topology_to_h5msm(item.topology, handler, atom_indices=atom_indices)
#      16 _add_structures_to_h5msm(item.structures, handler, atom_indices=atom_indices, structure_indices=structure_indices)
#      18 handler.close()
#
# File ~/repos@uibcdf/MolSysMT/molsysmt/form/molsysmt_Topology/to_file_h5msm.py:170, in _add_topology_to_h5msm(item, file, atom_indices)
#     167 chains['name'].resize((n_chains,))
#     168 chains['type'].resize((n_chains,))
# --> 170 chains['id'][:] = chains_df['chain_id'].to_numpy(dtype=int)
#     171 chains['name'][:] = chains_df['chain_name'].to_numpy(dtype=str)
#     172 chains['type'][:] = chains_df['chain_type'].to_numpy(dtype=str)
#
# File ~/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/pandas/core/base.py:637, in IndexOpsMixin.to_numpy(self, dtype, copy, na_value, **kwargs)
#     549 """
#     550 A NumPy ndarray representing the values in this Series or Index.
#     551
#    (...)
#     634       dtype='datetime64[ns]')
#     635 """
#     636 if isinstance(self.dtype, ExtensionDtype):
# --> 637     return self.array.to_numpy(dtype, copy=copy, na_value=na_value, **kwargs)
#     638 elif kwargs:
#     639     bad_keys = next(iter(kwargs.keys()))
#
# File ~/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/pandas/core/arrays/masked.py:487, in BaseMaskedArray.to_numpy(self, dtype, copy, na_value)
#     481 if self._hasna:
#     482     if (
#     483         dtype != object
#     484         and not is_string_dtype(dtype)
#     485         and na_value is libmissing.NA
#     486     ):
# --> 487         raise ValueError(
#     488             f"cannot convert to '{dtype}'-dtype NumPy array "
#     489             "with missing values. Specify an appropriate 'na_value' "
#     490             "for this dtype."
#     491         )
#     492     # don't pass copy to astype -> always need a copy since we are mutating
#     493     with warnings.catch_warnings():
#
# ValueError: cannot convert to 'int64'-dtype NumPy array with missing values. Specify an appropriate 'na_value' for this dtype.

# %%
# quiero llegar aqui:
# msm.convert(tests_systems['proline dipeptide']['proline_dipeptide.msmpk'], to_form='molsysmt.MolSys')
