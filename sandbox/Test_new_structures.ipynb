# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Test new structures

# %%
import molsysmt as msm

# %%
openmm_Topology = msm.build.build_peptide('AceProNme', to_form='openmm.Topology')

# %%
msm.get(openmm_Topology, element='entity', n_molecules=True)
# Out:
# entra
# entra 2
# entra 3
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2883011/3738893059.py", line 1, in <module>
#     msm.get(openmm_Topology, element='entity', n_molecules=True)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/../../_private/common_get.py", line 3644, in get_n_molecules_from_entity
#     if indices is None:
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/../../_private/common_get.py", line 3500, in get_molecule_index_from_entity
#     target_index_from_atom = get_entity_index_from_atom(item)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/../../_private/common_get.py", line 3596, in get_entity_index_from_entity
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 340, in get_n_entities_from_system
#     entity_index_from_atom = get_entity_index_from_atom(item)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
# ...
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/element/entity/get_entity_index.py", line 89, in get_entity_index
#     output = get(molecular_system, element=element, selection=selection, syntax=syntax,
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/basic/get.py", line 196, in get
#     result = aux_get(aux_item, **dict_indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 119, in wrapper
#     return func(**final_args)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/form/openmm_Topology/get.py", line 106, in get_entity_index_from_atom
#     return _get(item, element='atom', selection=indices)
#   File "/home/diego/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py", line 57, in wrapper
#     signature = inspect.signature(func)
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/inspect.py", line 3254, in signature
#     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/inspect.py", line 3002, in from_callable
#     return _signature_from_callable(obj, sigcls=cls,
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/inspect.py", line 2463, in _signature_from_callable
#     return _signature_from_function(sigcls, obj,
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/inspect.py", line 2325, in _signature_from_function
#     parameters.append(Parameter(name, annotation=annotation,
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/inspect.py", line 2639, in __init__
#     self._kind = _ParameterKind(kind)
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/enum.py", line 385, in __call__
#     return cls.__new__(cls, value)
# RecursionError: maximum recursion depth exceeded while calling a Python object
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#   File "/home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
msm.get(openmm_Topology, n_entities=True)

# %%
molsysmt_Topology = msm.convert(openmm_Topology, 'molsysmt.Topology')
