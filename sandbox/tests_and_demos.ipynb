# %%
import molsysmt as msm

# %%
molecular_system = msm.convert(msm.systems.demo['Barnase-Barstar']['barnase_barstar.msmpk'])

# %%
msm.structure.get_distances(molecular_system, selection='all in groups of molecule_name=="Barnase"',
                 selection_2='all in groups of molecule_name=="Barstar"')
# Out:
# array([[[3.5047525 , 4.23936118, 3.94088285, ..., 3.83686552,
#          3.4918292 , 3.24047558],
#         [3.7062074 , 4.41749547, 4.09492126, ..., 3.95970911,
#          3.55834294, 3.38178039],
#         [3.31199802, 4.01788494, 3.6602229 , ..., 4.30847228,
#          4.01067446, 3.78287416],
#         ...,
#         [1.73941781, 2.28623987, 2.25380662, ..., 3.05194594,
#          3.47264271, 3.45030148],
#         [2.32129054, 2.85032524, 2.85862932, ..., 3.62103347,
#          4.04098148, 4.03008283],
#         [2.31249994, 2.92649829, 2.88605194, ..., 3.6516116 ,
#          4.07026928, 4.09737834]]]) <Unit('nanometer')>
