# %%
import molsysmt as msm
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import molsysmt as msm
#
# File ~/projects@dprada/MolSysMT/molsysmt/__init__.py:22
#      19 from .basic import *
#      20 from . import basic
# ---> 22 from . import form
#      23 from . import element
#      25 from . import topology
#
# File ~/projects@dprada/MolSysMT/molsysmt/form/__init__.py:13
#      11 for f in os.scandir(current_dir):
#      12     if f.is_dir() and f.name not in ['__pycache__']:
# ---> 13         mod = import_module('molsysmt.form.'+f.name)
#      14         _dict_modules[mod.form_name] = mod
#      16 _dict_forms_lowercase = {ii.lower(): ii for ii in _dict_modules.keys()}
#
# File /conda/miniconda3/envs/MolSysMT@dprada_3.9/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# ...
