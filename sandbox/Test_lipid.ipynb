# %% [markdown]
# # Test lipid

# %%
import molsysmt as msm

# %%
molsys = msm.convert('./popc_1.crd', to_form='molsysmt.MolSys')

# %%
molsys.topology.atoms_dataframe
# Out:
#     atom_index atom_name  atom_id atom_type group_index group_name  group_id  \
# 0         None         N        1         N        None       POPC         1
# 1         None       C12        2       C12        None       POPC         1
# 2         None      H12A        3      H12A        None       POPC         1
# 3         None      H12B        4      H12B        None       POPC         1
# 4         None       C13        5       C13        None       POPC         1
# ..         ...       ...      ...       ...         ...        ...       ...
# 129       None      H15Y      130      H15Y        None       POPC         1
# 130       None      C316      131      C316        None       POPC         1
# 131       None      H16X      132      H16X        None       POPC         1
# 132       None      H16Y      133      H16Y        None       POPC         1
# 133       None      H16Z      134      H16Z        None       POPC         1
#
# ...
