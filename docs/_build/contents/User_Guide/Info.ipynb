# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
# Out:
# _ColormakerRegistry()

# %% [markdown]
# # Printing out a summary information on a molecular system

# %% [markdown]
# There is in MolSysMT a method to print out a brief overview of a molecular system and its elements. The output of this method can be a `pandas.DataFrame` or a `string`. Lets load a molecular system to illustrate with some simple examples how it works:

# %%
molecular_system = msm.convert('1tcd.mmtf')

# %% [markdown]
# ## As a DataFrame

# %% [markdown]
# ### Summary information on atoms
#
# The method `molsysmt.info()` can be applied over any element of the molecular system. Lets see an example where the summary information is shown for a set of atoms when the input argument `output='dataframe'`:

# %%
msm.info(molecular_system, target='atom', indices=[9,10,11,12], output='dataframe')
# Out:
# <style  type="text/css" >
# </style><table id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9" ><thead>    <tr>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >id</th>        <th class="col_heading level0 col2" >name</th>        <th class="col_heading level0 col3" >type</th>        <th class="col_heading level0 col4" >group index</th>        <th class="col_heading level0 col5" >group id</th>        <th class="col_heading level0 col6" >group name</th>        <th class="col_heading level0 col7" >group type</th>        <th class="col_heading level0 col8" >component index</th>        <th class="col_heading level0 col9" >chain index</th>        <th class="col_heading level0 col10" >molecule index</th>        <th class="col_heading level0 col11" >molecule type</th>        <th class="col_heading level0 col12" >entity index</th>        <th class="col_heading level0 col13" >entity name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col0" class="data row0 col0" >9</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col1" class="data row0 col1" >10</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col2" class="data row0 col2" >N</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col3" class="data row0 col3" >N</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col5" class="data row0 col5" >5</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col6" class="data row0 col6" >PRO</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col7" class="data row0 col7" >aminoacid</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col10" class="data row0 col10" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col11" class="data row0 col11" >protein</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row0_col13" class="data row0 col13" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col0" class="data row1 col0" >10</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col1" class="data row1 col1" >11</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col2" class="data row1 col2" >CA</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col3" class="data row1 col3" >C</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col4" class="data row1 col4" >1</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col5" class="data row1 col5" >5</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col6" class="data row1 col6" >PRO</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col7" class="data row1 col7" >aminoacid</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col8" class="data row1 col8" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col9" class="data row1 col9" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col11" class="data row1 col11" >protein</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row1_col13" class="data row1 col13" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col0" class="data row2 col0" >11</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col1" class="data row2 col1" >12</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col2" class="data row2 col2" >C</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col3" class="data row2 col3" >C</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col5" class="data row2 col5" >5</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col6" class="data row2 col6" >PRO</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col7" class="data row2 col7" >aminoacid</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col8" class="data row2 col8" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col9" class="data row2 col9" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col10" class="data row2 col10" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col11" class="data row2 col11" >protein</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col12" class="data row2 col12" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row2_col13" class="data row2 col13" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col0" class="data row3 col0" >12</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col1" class="data row3 col1" >13</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col2" class="data row3 col2" >O</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col3" class="data row3 col3" >O</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col5" class="data row3 col5" >5</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col6" class="data row3 col6" >PRO</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col7" class="data row3 col7" >aminoacid</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col8" class="data row3 col8" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col9" class="data row3 col9" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col10" class="data row3 col10" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col11" class="data row3 col11" >protein</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col12" class="data row3 col12" >0</td>
#                         <td id="T_23b66de4_9a52_11ea_9deb_ab2c98f556e9row3_col13" class="data row3 col13" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# The method can also take a selection input argument:

# %%
msm.info(molecular_system, target='atom', selection='group.index==6')
# Out:
# <style  type="text/css" >
# </style><table id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9" ><thead>    <tr>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >id</th>        <th class="col_heading level0 col2" >name</th>        <th class="col_heading level0 col3" >type</th>        <th class="col_heading level0 col4" >group index</th>        <th class="col_heading level0 col5" >group id</th>        <th class="col_heading level0 col6" >group name</th>        <th class="col_heading level0 col7" >group type</th>        <th class="col_heading level0 col8" >component index</th>        <th class="col_heading level0 col9" >chain index</th>        <th class="col_heading level0 col10" >molecule index</th>        <th class="col_heading level0 col11" >molecule type</th>        <th class="col_heading level0 col12" >entity index</th>        <th class="col_heading level0 col13" >entity name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col0" class="data row0 col0" >45</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col1" class="data row0 col1" >46</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col2" class="data row0 col2" >N</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col3" class="data row0 col3" >N</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col4" class="data row0 col4" >6</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col5" class="data row0 col5" >10</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col6" class="data row0 col6" >ALA</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col7" class="data row0 col7" >aminoacid</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col10" class="data row0 col10" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col11" class="data row0 col11" >protein</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col12" class="data row0 col12" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row0_col13" class="data row0 col13" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col0" class="data row1 col0" >46</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col1" class="data row1 col1" >47</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col2" class="data row1 col2" >CA</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col3" class="data row1 col3" >C</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col4" class="data row1 col4" >6</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col5" class="data row1 col5" >10</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col6" class="data row1 col6" >ALA</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col7" class="data row1 col7" >aminoacid</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col8" class="data row1 col8" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col9" class="data row1 col9" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col10" class="data row1 col10" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col11" class="data row1 col11" >protein</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col12" class="data row1 col12" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row1_col13" class="data row1 col13" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col0" class="data row2 col0" >47</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col1" class="data row2 col1" >48</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col2" class="data row2 col2" >C</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col3" class="data row2 col3" >C</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col4" class="data row2 col4" >6</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col5" class="data row2 col5" >10</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col6" class="data row2 col6" >ALA</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col7" class="data row2 col7" >aminoacid</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col8" class="data row2 col8" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col9" class="data row2 col9" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col10" class="data row2 col10" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col11" class="data row2 col11" >protein</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col12" class="data row2 col12" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row2_col13" class="data row2 col13" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col0" class="data row3 col0" >48</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col1" class="data row3 col1" >49</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col2" class="data row3 col2" >O</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col3" class="data row3 col3" >O</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col4" class="data row3 col4" >6</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col5" class="data row3 col5" >10</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col6" class="data row3 col6" >ALA</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col7" class="data row3 col7" >aminoacid</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col8" class="data row3 col8" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col9" class="data row3 col9" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col10" class="data row3 col10" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col11" class="data row3 col11" >protein</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col12" class="data row3 col12" >0</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row3_col13" class="data row3 col13" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row4_col0" class="data row4 col0" >49</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row4_col1" class="data row4 col1" >50</td>
#                         <td id="T_260ae4f8_9a52_11ea_9deb_ab2c98f556e9row4_col2" class="data row4 col2" >CB</td>

# %% [markdown]
# Notice that the default option for `output` is 'dataframe'.

# %% [markdown]
# ### Summary information on groups
#
# Lets see an example where the summary information is shown for a set of groups:

# %%
msm.info(molecular_system, target='group', indices=[20,21,22,23])
# Out:
# <style  type="text/css" >
# </style><table id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9" ><thead>    <tr>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >id</th>        <th class="col_heading level0 col2" >name</th>        <th class="col_heading level0 col3" >type</th>        <th class="col_heading level0 col4" >n atoms</th>        <th class="col_heading level0 col5" >component index</th>        <th class="col_heading level0 col6" >chain index</th>        <th class="col_heading level0 col7" >molecule index</th>        <th class="col_heading level0 col8" >molecule type</th>        <th class="col_heading level0 col9" >entity index</th>        <th class="col_heading level0 col10" >entity name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col0" class="data row0 col0" >20</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col1" class="data row0 col1" >24</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col2" class="data row0 col2" >PRO</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col3" class="data row0 col3" >aminoacid</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col4" class="data row0 col4" >7</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col8" class="data row0 col8" >protein</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row0_col10" class="data row0 col10" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col0" class="data row1 col0" >21</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col1" class="data row1 col1" >25</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col2" class="data row1 col2" >LEU</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col3" class="data row1 col3" >aminoacid</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col4" class="data row1 col4" >8</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col8" class="data row1 col8" >protein</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col9" class="data row1 col9" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row1_col10" class="data row1 col10" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col0" class="data row2 col0" >22</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col1" class="data row2 col1" >26</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col2" class="data row2 col2" >ILE</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col3" class="data row2 col3" >aminoacid</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col4" class="data row2 col4" >8</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col6" class="data row2 col6" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col8" class="data row2 col8" >protein</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col9" class="data row2 col9" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row2_col10" class="data row2 col10" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col0" class="data row3 col0" >23</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col1" class="data row3 col1" >27</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col2" class="data row3 col2" >GLU</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col3" class="data row3 col3" >aminoacid</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col4" class="data row3 col4" >9</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col6" class="data row3 col6" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col7" class="data row3 col7" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col8" class="data row3 col8" >protein</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col9" class="data row3 col9" >0</td>
#                         <td id="T_2839d590_9a52_11ea_9deb_ab2c98f556e9row3_col10" class="data row3 col10" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Summary information on components
#
# Find here now an example on how the method `molsysmt.info()` works over components:

# %%
msm.info(molecular_system, target='component', selection='molecule.type!="water"')
# Out:
# <style  type="text/css" >
# </style><table id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9" ><thead>    <tr>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >n atoms</th>        <th class="col_heading level0 col2" >n groups</th>        <th class="col_heading level0 col3" >chain index</th>        <th class="col_heading level0 col4" >molecule index</th>        <th class="col_heading level0 col5" >molecule type</th>        <th class="col_heading level0 col6" >entity index</th>        <th class="col_heading level0 col7" >entity name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row0_col1" class="data row0 col1" >1906</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row0_col2" class="data row0 col2" >248</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row0_col5" class="data row0 col5" >protein</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row0_col7" class="data row0 col7" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row1_col1" class="data row1 col1" >1912</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row1_col2" class="data row1 col2" >249</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row1_col3" class="data row1 col3" >1</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row1_col4" class="data row1 col4" >0</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row1_col5" class="data row1 col5" >protein</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_29ad4bfa_9a52_11ea_9deb_ab2c98f556e9row1_col7" class="data row1 col7" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Summary information on chains
#
# If the summary information on all chains in the molecular system needs to be printed out:

# %%
msm.info(molecular_system, target='chain')
# Out:
# <style  type="text/css" >
# </style><table id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9" ><thead>    <tr>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >id</th>        <th class="col_heading level0 col2" >name</th>        <th class="col_heading level0 col3" >n atoms</th>        <th class="col_heading level0 col4" >n groups</th>        <th class="col_heading level0 col5" >n components</th>        <th class="col_heading level0 col6" >molecule index</th>        <th class="col_heading level0 col7" >molecule type</th>        <th class="col_heading level0 col8" >entity index</th>        <th class="col_heading level0 col9" >entity name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col1" class="data row0 col1" >A</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col2" class="data row0 col2" >A</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col3" class="data row0 col3" >1906</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col4" class="data row0 col4" >248</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col7" class="data row0 col7" >protein</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col8" class="data row0 col8" >0</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row0_col9" class="data row0 col9" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col1" class="data row1 col1" >B</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col2" class="data row1 col2" >B</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col3" class="data row1 col3" >1912</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col4" class="data row1 col4" >249</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col5" class="data row1 col5" >1</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col7" class="data row1 col7" >protein</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col8" class="data row1 col8" >0</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row1_col9" class="data row1 col9" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#             <tr>
#                                 <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col1" class="data row2 col1" >C</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col2" class="data row2 col2" >A</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col3" class="data row2 col3" >73</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col4" class="data row2 col4" >73</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col5" class="data row2 col5" >73</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col6" class="data row2 col6" >[ 1  2  3 ... 71 72 73]</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col7" class="data row2 col7" >['water' 'water' 'water' ... 'water' 'water' 'water']</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col8" class="data row2 col8" >1</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row2_col9" class="data row2 col9" >water</td>
#             </tr>
#             <tr>
#                                 <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col1" class="data row3 col1" >D</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col2" class="data row3 col2" >B</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col3" class="data row3 col3" >92</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col4" class="data row3 col4" >92</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col5" class="data row3 col5" >92</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col6" class="data row3 col6" >[ 74  75  76 ... 163 164 165]</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col7" class="data row3 col7" >['water' 'water' 'water' ... 'water' 'water' 'water']</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col8" class="data row3 col8" >1</td>
#                         <td id="T_2bb68f4c_9a52_11ea_9deb_ab2c98f556e9row3_col9" class="data row3 col9" >water</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Summary information on molecules
#
# The following is an example on how the method works when the targetted element is 'molecule':

# %%
msm.info(molecular_system, target='molecule', selection='molecule.type!="water"')
# Out:
# <style  type="text/css" >
# </style><table id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9" ><thead>    <tr>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >type</th>        <th class="col_heading level0 col3" >n atoms</th>        <th class="col_heading level0 col4" >n groups</th>        <th class="col_heading level0 col5" >n components</th>        <th class="col_heading level0 col6" >chain index</th>        <th class="col_heading level0 col7" >entity index</th>        <th class="col_heading level0 col8" >entity name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9row0_col1" class="data row0 col1" >TRIOSEPHOSPHATE ISOMERASE</td>
#                         <td id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9row0_col2" class="data row0 col2" >protein</td>
#                         <td id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9row0_col3" class="data row0 col3" >3818</td>
#                         <td id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9row0_col4" class="data row0 col4" >497</td>
#                         <td id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9row0_col5" class="data row0 col5" >2</td>
#                         <td id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9row0_col6" class="data row0 col6" >[0 1]</td>
#                         <td id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_2da750c0_9a52_11ea_9deb_ab2c98f556e9row0_col8" class="data row0 col8" >TRIOSEPHOSPHATE ISOMERASE</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Summary information on entities
#
# If the targetted element is 'entity' the method prints out the next summary information:

# %%
msm.info(molecular_system, target='entity')
# Out:
# <style  type="text/css" >
# </style><table id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9" ><thead>    <tr>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >name</th>        <th class="col_heading level0 col2" >type</th>        <th class="col_heading level0 col3" >n atoms</th>        <th class="col_heading level0 col4" >n groups</th>        <th class="col_heading level0 col5" >n components</th>        <th class="col_heading level0 col6" >n chains</th>        <th class="col_heading level0 col7" >n molecules</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row0_col1" class="data row0 col1" >TRIOSEPHOSPHATE ISOMERASE</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row0_col2" class="data row0 col2" >protein</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row0_col3" class="data row0 col3" >3818</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row0_col4" class="data row0 col4" >497</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row0_col5" class="data row0 col5" >2</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row0_col6" class="data row0 col6" >2</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row0_col7" class="data row0 col7" >1</td>
#             </tr>
#             <tr>
#                                 <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row1_col1" class="data row1 col1" >water</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row1_col2" class="data row1 col2" >water</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row1_col3" class="data row1 col3" >165</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row1_col4" class="data row1 col4" >165</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row1_col5" class="data row1 col5" >165</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row1_col6" class="data row1 col6" >2</td>
#                         <td id="T_2f24773e_9a52_11ea_9deb_ab2c98f556e9row1_col7" class="data row1 col7" >165</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ### Summary information on a molecular system
#
# At last, a summary information can be shown on the whole molecular system as follows:

# %%
msm.info(molecular_system)
# Out:
# <style  type="text/css" >
# </style><table id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9" ><thead>    <tr>        <th class="col_heading level0 col0" >form</th>        <th class="col_heading level0 col1" >n atoms</th>        <th class="col_heading level0 col2" >n groups</th>        <th class="col_heading level0 col3" >n components</th>        <th class="col_heading level0 col4" >n chains</th>        <th class="col_heading level0 col5" >n molecules</th>        <th class="col_heading level0 col6" >n entities</th>        <th class="col_heading level0 col7" >n waters</th>        <th class="col_heading level0 col8" >n proteins</th>        <th class="col_heading level0 col9" >n frames</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#                         <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col1" class="data row0 col1" >3983</td>
#                         <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col2" class="data row0 col2" >662</td>
#                         <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col3" class="data row0 col3" >167</td>
#                         <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col4" class="data row0 col4" >4</td>
#                         <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col5" class="data row0 col5" >166</td>
#                         <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col6" class="data row0 col6" >2</td>
#                         <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col7" class="data row0 col7" >165</td>
#                         <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col8" class="data row0 col8" >1</td>
#                         <td id="T_316161f6_9a52_11ea_9deb_ab2c98f556e9row0_col9" class="data row0 col9" >1</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## As a string
#
# The method `molsysmt.info()` can also return a string, short or long, with key information to identify the targetted element.

# %% [markdown]
# ### Summary information on atoms
#
# If we only need to get a short string encoding the main attributes of an atom, the input argument `output` should take the value 'short_string':

# %%
msm.info(molecular_system, target='atom', indices=10, output='short_string')
# Out:
# 'CA-11@10'

# %% [markdown]
# The string is nothing but the atom name, the atom id and the atom index with '-' between the name and the id, and '@' between the id and the index. The input argument `indices` accepts also a list of indices:

# %%
msm.info(molecular_system, target='atom', indices=[10,11,12,13], output='short_string')
# Out:
# ['CA-11@10', 'C-12@11', 'O-13@12', 'CB-14@13']

# %% [markdown]
# The long version of the string includes the short string of the group, chain and molecule the atom belongs to; with the character '/' in between:

# %%
msm.info(molecular_system, target='atom', indices=10, output='long_string')
# Out:
# 'CA-11@10/PRO-5@1/A-A@0/TRIOSEPHOSPHATE ISOMERASE@0'

# %% [markdown]
# ### Summary information on groups
#
# The short string corresponding to a group is composed of its name, id and index. The characters used as separators are the same as with atoms: '-' between name and id, and '@' between id and index.

# %%
msm.info(molecular_system, target='group', indices=0, output='short_string')
# Out:
# 'LYS-4@0'

# %% [markdown]
# The long version of the string includes the short string for the chain and molecule the group belongs to:

# %%
msm.info(molecular_system, target='group', indices=3, output='long_string')
# Out:
# 'PRO-7@3/A-A@0/TRIOSEPHOSPHATE ISOMERASE@0'

# %% [markdown]
# ### Summary information on components

# %% [markdown]
# The short string with the summary information of a component is its index only:

# %%
msm.info(molecular_system, target='component', indices=2, output='short_string')
# Out:
# '2'

# %% [markdown]
# The long version of the string includes the chain and molecule the component belongs to with the character '/' as separator.

# %%
msm.info(molecular_system, target='component', indices=2, output='long_string')
# Out:
# '2/A-C@2/water@1'

# %% [markdown]
# ### Summary information on chains

# %% [markdown]
# Just like with atoms and groups, the short version of the chain string is made up of the sequence of atributes: name, id and index. The character '-' is in between the chain name and the chain id, and '@' precedes the chain index:

# %%
msm.info(molecular_system, target='chain', indices=2, output='short_string')
# Out:
# 'A-C@2'

# %% [markdown]
# The long version of the string in this case is the same as the short one:

# %%
msm.info(molecular_system, target='chain', indices=2, output='long_string')
# Out:
# 'A-C@2'

# %% [markdown]
# ### Summary information on molecules
#
# Molecules have no relevant id attributes, thats why in this case the short string is the molecule name followed by the character '@' and the molecule index:

# %%
msm.info(molecular_system, target='molecule', indices=0, output='short_string')
# Out:
# 'TRIOSEPHOSPHATE ISOMERASE@0'

# %% [markdown]
# As well as with chains, the short and long strings are equivalent here:

# %%
msm.info(molecular_system, target='molecule', indices=0, output='long_string')
# Out:
# 'TRIOSEPHOSPHATE ISOMERASE@0'

# %% [markdown]
# ### Summary information on entities

# %% [markdown]
# The significant attributes for entities are only two. In this case the string takes the same coding as before, with the character '@' between the name and the index.

# %%
msm.info(molecular_system, target='entity', indices=0, output='short_string')
# Out:
# 'TRIOSEPHOSPHATE ISOMERASE@0'

# %% [markdown]
# The long string is equal to the short string when the targetted element is an entity:

# %%
msm.info(molecular_system, target='entity', indices=0, output='long_string')
# Out:
# 'TRIOSEPHOSPHATE ISOMERASE@0'
