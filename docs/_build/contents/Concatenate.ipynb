# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
import simtk.unit as unit

# %% [markdown]
# # Concatenate Molecular Systems

# %% [markdown]
# A list of molecular systems are concatenated in to a new molecular system. They all can have different forms but must have the same topology (they must be the same molecular system, in deed). The resultant object will contain all coordinates (frames) in the same order they were concatenated.

# %%
molecular_system_1 = msm.build_peptide('aminoacids3:AceAlaNme')

# %%
molecular_system_1 = msm.build_peptide('aminoacids3:AceAlaNme')
molecular_system_2 = msm.copy(molecular_system_1)
molecular_system_3 = msm.copy(molecular_system_1)
molecular_system_4 = msm.copy(molecular_system_1)

msm.translate(molecular_system_2, translation=[0.1, 0.1, 0.1]*unit.nanometers)
msm.translate(molecular_system_3, translation=[0.2, 0.2, 0.2]*unit.nanometers)
msm.translate(molecular_system_4, translation=[0.3, 0.3, 0.3]*unit.nanometers)

# %%
molecular_system_total = msm.concatenate([molecular_system_1, molecular_system_2, molecular_system_3,
                                          molecular_system_4])

# %%
msm.info(molecular_system_total)
# Out:
# <style  type="text/css" >
# </style><table id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26" ><thead>    <tr>        <th class="col_heading level0 col0" >form</th>        <th class="col_heading level0 col1" >n_atoms</th>        <th class="col_heading level0 col2" >n_groups</th>        <th class="col_heading level0 col3" >n_components</th>        <th class="col_heading level0 col4" >n_chains</th>        <th class="col_heading level0 col5" >n_molecules</th>        <th class="col_heading level0 col6" >n_entities</th>        <th class="col_heading level0 col7" >n_peptides</th>        <th class="col_heading level0 col8" >n_frames</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#                         <td id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26row0_col1" class="data row0 col1" >22</td>
#                         <td id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_47020fce_39a3_11eb_b69c_1c1b0d075c26row0_col8" class="data row0 col8" >4</td>
#             </tr>
#     </tbody></table>

# %%
msm.view(molecular_system_total)
# Out:
# NGLWidget(max_frame=3)
