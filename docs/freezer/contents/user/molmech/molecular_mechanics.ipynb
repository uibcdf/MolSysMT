# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm

# %% [markdown]
# # Molecular Mechanics

# %%
item = {'forcefield':'patata'}

# %%
msm.get_form(item)
# Out:
# 'MolecularMechanicsDict'

# %%
item = msm.convert(item, to_form='molsysmt.MolecularMechanics')

# %%
msm.get_form(item)
# Out:
# 'molsysmt.MolecularMechanics'

# %%
item.__dict__
# Out:
# {'_molecular_system': None,
#  'forcefield': 'patata',
#  'non_bonded_method': 'no_cutoff',
#  'non_bonded_cutoff': None,
#  'switch_distance': None,
#  'use_dispersion_correction': False,
#  'ewald_error_tolerance': 0.0001,
#  'hydrogen_mass': None,
#  'constraints': None,
#  'flexible_constraints': False,
#  'water_model': None,
#  'rigid_water': True,
#  'residue_templates': {},
#  'ignore_external_bonds': False,
#  'implicit_solvent': None,
#  'solute_dielectric': 1.0,
#  'solvent_dielectric': 78.5,
#  'implicit_solvent_salt_conc': '0.0 mol/L',
#  'implicit_solvent_kappa': '0.0 1/nm'}

# %%
file_path = msm.demo_systems.files['1tcd.pdb']
molecular_system_A = msm.convert(file_path)
molecular_system_A = msm.remove_solvent(molecular_system_A)
molecular_system_A = msm.add_missing_hydrogens(molecular_system_A)

# %%
from molsysmt.molecular_system import MolecularSystem

# %%
molecular_system = MolecularSystem(molecular_system_A)

# %%
molecular_system.__dict__
# Out:
# {'elements_item': <molsysmt.native.molsys.MolSys at 0x7f5b82c1f3d0>,
#  'elements_form': 'molsysmt.MolSys',
#  'bonds_item': <molsysmt.native.molsys.MolSys at 0x7f5b82c1f3d0>,
#  'bonds_form': 'molsysmt.MolSys',
#  'coordinates_item': <molsysmt.native.molsys.MolSys at 0x7f5b82c1f3d0>,
#  'coordinates_form': 'molsysmt.MolSys',
#  'velocities_item': None,
#  'velocities_form': None,
#  'box_item': <molsysmt.native.molsys.MolSys at 0x7f5b82c1f3d0>,
#  'box_form': 'molsysmt.MolSys',
#  'ff_parameters_item': None,
#  'ff_parameters_form': None,
#  'mm_parameters_item': None,
#  'mm_parameters_form': None,
#  'thermo_state_item': None,
#  'thermo_state_form': None,
#  'simulation_item': None,
#  'simulation_form': None}

# %%
mm_parameters = {'forcefield':'AMBER14'}

# %%
molecular_system = MolecularSystem([molecular_system_A, mm_parameters])

# %%
from molsysmt.tools.molecular_systems import is_a_single_molecular_system

# %%
is_a_single_molecular_system([molecular_system_A, mm_parameters])
# Out:
# True

# %%
aa = msm.convert([molecular_system_A, mm_parameters], to_form='molsysmt.MolecularMechanics')

# %%
from molsysmt.native.simulation import simulation_to_potential_energy_minimization

# %%
msm.get_form(simulation_to_potential_energy_minimization)
# Out:
# 'molsysmt.Simulation'

# %%
top = msm.convert(molecular_system_A, to_form='openmm.Topology')

# %%
aa = MolecularSystem([top, mm_parameters, simulation_to_potential_energy_minimization])

# %%
aa.__dict__
# Out:
# {'elements_item': <Topology; 2 chains, 497 residues, 7707 atoms, 7779 bonds>,
#  'elements_form': 'openmm.Topology',
#  'bonds_item': <Topology; 2 chains, 497 residues, 7707 atoms, 7779 bonds>,
#  'bonds_form': 'openmm.Topology',
#  'coordinates_item': None,
#  'coordinates_form': None,
#  'velocities_item': None,
#  'velocities_form': None,
#  'box_item': <Topology; 2 chains, 497 residues, 7707 atoms, 7779 bonds>,
#  'box_form': 'openmm.Topology',
#  'ff_parameters_item': {'forcefield': 'AMBER14'},
#  'ff_parameters_form': 'MolecularMechanicsDict',
#  'mm_parameters_item': {'forcefield': 'AMBER14'},
#  'mm_parameters_form': 'MolecularMechanicsDict',
#  'thermo_state_item': <molsysmt.native.simulation.Simulation at 0x7f5ac038dd90>,
#  'thermo_state_form': 'molsysmt.Simulation',
#  'simulation_item': <molsysmt.native.simulation.Simulation at 0x7f5ac038dd90>,
#  'simulation_form': 'molsysmt.Simulation'}

# %%
tmp_item = msm.convert([molecular_system_A, mm_parameters,
                        simulation_to_potential_energy_minimization],
                       to_form='openmm.Simulation')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-1240c2b547c6> in <module>
#       1 tmp_item = msm.convert([molecular_system_A, mm_parameters,
#       2                         simulation_to_potential_energy_minimization],
# ----> 3                        to_form='openmm.Simulation')
#
# ~/Projects/MolSysMT/molsysmt/multitool/convert.py in convert(molecular_system, to_form, selection, frame_indices, syntax, **kwargs)
#      97     else:
#      98         tmp_item, _ = dict_convert[item_form][to_form](item, molecular_system, atom_indices=atom_indices, frame_indices=frame_indices,
# ---> 99                                                      **conversion_arguments, **kwargs)
#     100
#     101     tmp_item = digest_output(tmp_item)
#
# ~/Projects/MolSysMT/molsysmt/forms/classes/api_molsysmt_MolSys.py in to_openmm_Simulation(item, molecular_system, atom_indices, frame_indices)
#     128     from molsysmt.native.io.molsys.classes import to_openmm_Simulation as molsysmt_MolSys_to_openmm_Simulation
#     129
# --> 130     tmp_item, tmp_molecular_system = molsysmt_MolSys_to_openmm_Simulation(item, molecular_system=molecular_system, atom_indices=atom_indices, frame_indices=frame_indices)
#     131
#     132     return tmp_item, tmp_molecular_system
#
# ~/Projects/MolSysMT/molsysmt/native/io/molsys/classes/openmm_Simulation.py in to_openmm_Simulation(item, molecular_system, atom_indices, frame_indices)
#       5
#       6     tmp_item, tmp_molecular_system = molsysmt_MolSys_to_openmm_Topology(item, molecular_system, atom_indices=atom_indices, frame_indices=frame_indices)
# ----> 7     tmp_item, tmp_molecular_system = openmm_Topology_to_openmm_Simulation(tmp_item, tmp_molecular_system, atom_indices='all', frame_indices=0)
#       8
#       9     return tmp_item, tmp_molecular_system
#
# ~/Projects/MolSysMT/molsysmt/forms/classes/api_openmm_Topology.py in to_openmm_Simulation(item, molecular_system, atom_indices, frame_indices)
#     117
#     118     tmp_item, tmp_molecular_system = to_openmm_System(item, molecular_system=molecular_system, atom_indices=atom_indices, frame_indices=frame_indices)
# --> 119     tmp_item, tmp_molecular_system = openmm_System_to_openmm_Simulation(tmp_item, molecular_system=tmp_molecular_system)
#     120
#     121     return tmp_item, tmp_molecular_system
#
# ~/Projects/MolSysMT/molsysmt/forms/classes/api_openmm_System.py in to_openmm_Simulation(item, molecular_system, atom_indices, frame_indices)
#      52     topology = convert(molecular_system, to_form='openmm.Topology', selection=atom_indices)
#      53     positions = get(molecular_system, target='atom', selection=atom_indices, frame_indices=frame_indices, coordinates=True)
# ---> 54     positions = puw.convert(positions[0], to_units='nm', to_form='simtk.unit')
#      55     simulation = convert(molecular_system, to_form='molsysmt.Simulation')
#      56
#
# TypeError: convert() got an unexpected keyword argument 'to_units'

# %%
tmp_item = msm.convert([molecular_system_A, mm_parameters,
                        simulation_to_potential_energy_minimization],
                       to_form='openmm.Context')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/Myopt/miniconda3/envs/MolSysMT_env/lib/python3.7/site-packages/pyunitwizard/main.py in get_form(quantity_or_unit)
#      28     try:
# ---> 29         return dict_is_form[type(quantity_or_unit)]
#      30     except:
#
# KeyError: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Myopt/miniconda3/envs/MolSysMT_env/lib/python3.7/site-packages/pyunitwizard/main.py in get_form(quantity_or_unit)
#      31         try:
# ---> 32             return dict_is_form[quantity_or_unit]
#      33         except:
#
# KeyError: '0 K'
#
# During handling of the above exception, another exception occurred:
#
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-23-bcc47c0ee8ab> in <module>
#       1 tmp_item = msm.convert([molecular_system_A, mm_parameters,
#       2                         simulation_to_potential_energy_minimization],
# ----> 3                        to_form='openmm.Context')
#
# ~/Projects/MolSysMT/molsysmt/multitool/convert.py in convert(molecular_system, to_form, selection, frame_indices, syntax, **kwargs)
#      97     else:
#      98         tmp_item, _ = dict_convert[item_form][to_form](item, molecular_system, atom_indices=atom_indices, frame_indices=frame_indices,
# ---> 99                                                      **conversion_arguments, **kwargs)
#     100
#     101     tmp_item = digest_output(tmp_item)
#
# ~/Projects/MolSysMT/molsysmt/forms/classes/api_molsysmt_MolSys.py in to_openmm_Context(item, molecular_system, atom_indices, frame_indices)
#     120     from molsysmt.native.io.molsys.classes import to_openmm_Context as molsysmt_MolSys_to_openmm_Context
#     121
# --> 122     tmp_item, tmp_molecular_system = molsysmt_MolSys_to_openmm_Context(item, molecular_system=molecular_system, atom_indices=atom_indices, frame_indices=frame_indices)
#     123
#     124     return tmp_item, tmp_molecular_system
#
# ~/Projects/MolSysMT/molsysmt/native/io/molsys/classes/openmm_Context.py in to_openmm_Context(item, molecular_system, atom_indices, frame_indices)
#       5
#       6     tmp_item, tmp_molecular_system = molsysmt_MolSys_to_openmm_Topology(item, molecular_system=molecular_system, atom_indices=atom_indices, frame_indices=frame_indices)
# ----> 7     tmp_item, tmp_molecular_system = openmm_Topology_to_openmm_Context(tmp_item, molecular_system=tmp_molecular_system, atom_indices='all', frame_indices=0)
#       8
#       9     return tmp_item, tmp_molecular_system
#
# ~/Projects/MolSysMT/molsysmt/forms/classes/api_openmm_Topology.py in to_openmm_Context(item, molecular_system, atom_indices, frame_indices)
#     108
#     109     tmp_item, tmp_molecular_system = to_openmm_System(item, molecular_system=molecular_system, atom_indices=atom_indices, frame_indices=frame_indices)
# --> 110     tmp_item, tmp_molecular_system = openmm_System_to_openmm_Context(tmp_item, molecular_system=tmp_molecular_system)
#     111
#     112     return tmp_item, tmp_molecular_system
#
# ~/Projects/MolSysMT/molsysmt/forms/classes/api_openmm_System.py in to_openmm_Context(item, molecular_system, atom_indices, frame_indices)
#      27     simulation = convert(molecular_system, to_form='molsysmt.Simulation')
#      28
# ---> 29     integrator = simulation.to_openmm_Integrator()
#      30     platform = simulation.to_openmm_Platform()
#      31
#
# ~/Projects/MolSysMT/molsysmt/native/simulation.py in to_openmm_Integrator(self)
#      79         from simtk.openmm import LangevinIntegrator
#      80
# ---> 81         temperature = puw.convert(self.temperature, to_unit='K', to_form='simtk.unit')
#      82         collisions_rate = puw.convert(self.collisions_rate, to_unit='1/ps', to_form='simtk.unit')
#      83         integration_timestep = puw.convert(self.integration_timestep, to_unit='fs', to_form='simtk.unit')
#
# ~/Myopt/miniconda3/envs/MolSysMT_env/lib/python3.7/site-packages/pyunitwizard/main.py in convert(quantity_or_unit, to_unit, to_form, parser)
#     187     output = None
#     188
# --> 189     form_in = get_form(quantity_or_unit)
#     190     to_form = digest_to_form(to_form)
#     191     parser = digest_parser(parser)
#
# ~/Myopt/miniconda3/envs/MolSysMT_env/lib/python3.7/site-packages/pyunitwizard/main.py in get_form(quantity_or_unit)
#      32             return dict_is_form[quantity_or_unit]
#      33         except:
# ---> 34             raise NotImplementedError("This quantity form was not implemented yet. Please open an issue to suggest its inclusion.")
#      35
#      36     return output
#
# NotImplementedError: This quantity form was not implemented yet. Please open an issue to suggest its inclusion.
