# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
# Out:
# /home/diego/Myusr/opt/miniconda3/envs/UIBCDF_lab_dev/lib/python3.7/site-packages/yank-0.24.2-py3.7-linux-x86_64.egg/yank/experiment.py:1170: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """)
# _ColormakerRegistry()

# %%
#molecular_system_a = msm.convert('mmtf:2GDL', 'molsysmt.MolSys')
#molecular_system_b = msm.convert('pdb:2GDL', 'molsysmt.MolSys')
#mmtf = msm.convert('pdb:2GDL', 'mmtf.MMTFDecoder')

# %%
molecular_system = msm.convert('1tcd.mmtf', 'molsysmt.MolSys')

# %%
bb = msm.extract(molecular_system, selection='chain.index==1')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-a45507b254cf> in <module>
# ----> 1 bb = msm.extract(molecular_system, selection='chain.index==1')
#
# ~/Proyectos/MolSysMT/molsysmt/multitool.py in extract(item, selection, frame_indices, to_form, syntaxis)
#     329         atom_indices = select(item=item, selection=selection, syntaxis=syntaxis)
#     330
# --> 331     tmp_item = _dict_extractor[form_in](item, atom_indices=atom_indices, frame_indices=frame_indices)
#     332
#     333     if form_in!=form_out:
#
# ~/Proyectos/MolSysMT/molsysmt/forms/classes/api_molsysmt_MolSys.py in extract(item, atom_indices, frame_indices)
#      86 def extract(item, atom_indices='all', frame_indices='all'):
#      87
# ---> 88     return item.extract(selection=atom_indices, frame_indices=frame_indices)
#      89
#      90 def to_nglview(item, atom_indices='all', frame_indices='all'):
#
# TypeError: extract() got an unexpected keyword argument 'selection'

# %%
bb.dataframe
# Out:
#       atom.index atom.name  atom.id atom.type  atom.formal_charge  \
# 0              0         N     1907         N                 0.0
# 1              1        CA     1908         C                 0.0
# 2              2         C     1909         C                 0.0
# 3              3         O     1910         O                 0.0
# 4              4        CB     1911         C                 0.0
# ...          ...       ...      ...       ...                 ...
# 1907        1907        CG     3814         C                 0.0
# 1908        1908        CD     3815         C                 0.0
# 1909        1909        CE     3816         C                 0.0
# 1910        1910        NZ     3817         N                 1.0
# 1911        1911       OXT     3818         O                 0.0
#
#      atom.bonded_atom_indices  group.index group.name  group.id group.type  \
# 0                         [1]            0        SER         3  aminoacid
# 1                   [0, 2, 4]            0        SER         3  aminoacid
# 2                   [1, 3, 6]            0        SER         3  aminoacid
# 3                         [2]            0        SER         3  aminoacid
# 4                      [1, 5]            0        SER         3  aminoacid
# ...                       ...          ...        ...       ...        ...
# 1907             [1906, 1908]          248        LYS       251  aminoacid
# 1908             [1907, 1909]          248        LYS       251  aminoacid
# 1909             [1908, 1910]          248        LYS       251  aminoacid
# 1910                   [1909]          248        LYS       251  aminoacid
# 1911                   [1904]          248        LYS       251  aminoacid
#
#       ...  chain.id chain.type molecule.index              molecule.name  \
# 0     ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
# 1     ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
# 2     ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
# 3     ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
# 4     ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
# ...   ...       ...        ...            ...                        ...
# 1907  ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
# 1908  ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
# 1909  ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
# 1910  ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
# 1911  ...         B        NaN              0  TRIOSEPHOSPHATE ISOMERASE
#
#       molecule.id molecule.type entity.index                entity.name  \
# 0               0       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 1               0       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 2               0       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 3               0       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 4               0       protein            0  TRIOSEPHOSPHATE ISOMERASE
# ...           ...           ...          ...                        ...
# 1907            0       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 1908            0       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 1909            0       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 1910            0       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 1911            0       protein            0  TRIOSEPHOSPHATE ISOMERASE
#
#       entity.id entity.type
# 0             0     protein
# 1             0     protein
# 2             0     protein
# 3             0     protein
# 4             0     protein
# ...         ...         ...
# 1907          0     protein
# 1908          0     protein
# 1909          0     protein
# 1910          0     protein
# 1911          0     protein
#
# [1912 rows x 26 columns]
