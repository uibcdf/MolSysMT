# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Barnase-Barstar complex

# %%
from openmm.app import PDBFile

# %%
xx=PDBFile('1brs.pdb')

# %%
xx.topology
# Out:
# <Topology; 12 chains, 1101 residues, 5149 atoms, 4738 bonds>

# %%
len(xx.positions)
# Out:
# 5149

# %%
import mdtraj as mdtraj

# %%
yy = mdtraj.load_

# %%
yy.topology.n_atoms
# Out:
# 5151

# %%
from pdbfixer import PDBFixer
import molsysmt as msm
# Out:
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.

# %%
pdb = PDBFixer(pdbid='1BRS')

# %%
list_atoms = list(pdb.topology.atoms())

# %%
list_chains=list(pdb.topology.chains())

# %%
len(list(list_chains[3].atoms()))
# Out:
# 691

# %%
list_bonds = list(pdb.topology.bonds())

# %%
list_atoms[0:10]
# Out:
# [<Atom 0 (N) of chain 0 residue 0 (VAL)>,
#  <Atom 1 (CA) of chain 0 residue 0 (VAL)>,
#  <Atom 2 (C) of chain 0 residue 0 (VAL)>,
#  <Atom 3 (O) of chain 0 residue 0 (VAL)>,
#  <Atom 4 (CB) of chain 0 residue 0 (VAL)>,
#  <Atom 5 (CG1) of chain 0 residue 0 (VAL)>,
#  <Atom 6 (CG2) of chain 0 residue 0 (VAL)>,
#  <Atom 7 (N) of chain 0 residue 1 (ILE)>,
#  <Atom 8 (CA) of chain 0 residue 1 (ILE)>,
#  <Atom 9 (C) of chain 0 residue 1 (ILE)>]

# %%
list_bonds[0:10]
# Out:
# [Bond(<Atom 2 (C) of chain 0 residue 0 (VAL)>, <Atom 1 (CA) of chain 0 residue 0 (VAL)>),
#  Bond(<Atom 2 (C) of chain 0 residue 0 (VAL)>, <Atom 3 (O) of chain 0 residue 0 (VAL)>),
#  Bond(<Atom 1 (CA) of chain 0 residue 0 (VAL)>, <Atom 4 (CB) of chain 0 residue 0 (VAL)>),
#  Bond(<Atom 1 (CA) of chain 0 residue 0 (VAL)>, <Atom 0 (N) of chain 0 residue 0 (VAL)>),
#  Bond(<Atom 4 (CB) of chain 0 residue 0 (VAL)>, <Atom 5 (CG1) of chain 0 residue 0 (VAL)>),
#  Bond(<Atom 4 (CB) of chain 0 residue 0 (VAL)>, <Atom 6 (CG2) of chain 0 residue 0 (VAL)>),
#  Bond(<Atom 2 (C) of chain 0 residue 0 (VAL)>, <Atom 7 (N) of chain 0 residue 1 (ILE)>),
#  Bond(<Atom 9 (C) of chain 0 residue 1 (ILE)>, <Atom 8 (CA) of chain 0 residue 1 (ILE)>),
#  Bond(<Atom 9 (C) of chain 0 residue 1 (ILE)>, <Atom 10 (O) of chain 0 residue 1 (ILE)>),
#  Bond(<Atom 8 (CA) of chain 0 residue 1 (ILE)>, <Atom 11 (CB) of chain 0 residue 1 (ILE)>)]

# %%
import networkx as nx

# %%
g=nx.Graph()
for bond in list_bonds:
    ind1 = bond.atom1.index
    ind2 = bond.atom2.index
    g.add_edge(ind1, ind2)

# %%
g=g.to_undirected()

# %%
bb = list(nx.components.connected_components(g))

# %%
for ii in bb:
    print(len(ii))
# Out:
# 864
# 878
# 839
# 691
# 665
# 699

# %%
msm.info(pdb, target='component')
# Out:
# <style type="text/css">
# </style>
# <table id="T_00455_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >index</th>
#       <th class="col_heading level0 col1" >n atoms</th>
#       <th class="col_heading level0 col2" >n groups</th>
#       <th class="col_heading level0 col3" >chain index</th>
#       <th class="col_heading level0 col4" >molecule index</th>
#       <th class="col_heading level0 col5" >molecule type</th>
#       <th class="col_heading level0 col6" >entity index</th>
#       <th class="col_heading level0 col7" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_00455_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_00455_row0_col1" class="data row0 col1" >864</td>
#       <td id="T_00455_row0_col2" class="data row0 col2" >108</td>
#       <td id="T_00455_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_00455_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_00455_row0_col5" class="data row0 col5" >protein</td>
#       <td id="T_00455_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_00455_row0_col7" class="data row0 col7" >Protein_0</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_00455_row1_col1" class="data row1 col1" >878</td>
#       <td id="T_00455_row1_col2" class="data row1 col2" >110</td>
#       <td id="T_00455_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_00455_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_00455_row1_col5" class="data row1 col5" >protein</td>
#       <td id="T_00455_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_00455_row1_col7" class="data row1 col7" >Protein_1</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_00455_row2_col1" class="data row2 col1" >839</td>
#       <td id="T_00455_row2_col2" class="data row2 col2" >108</td>
#       <td id="T_00455_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_00455_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_00455_row2_col5" class="data row2 col5" >protein</td>
#       <td id="T_00455_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_00455_row2_col7" class="data row2 col7" >Protein_2</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_00455_row3_col1" class="data row3 col1" >691</td>
#       <td id="T_00455_row3_col2" class="data row3 col2" >87</td>
#       <td id="T_00455_row3_col3" class="data row3 col3" >3</td>
#       <td id="T_00455_row3_col4" class="data row3 col4" >3</td>
#       <td id="T_00455_row3_col5" class="data row3 col5" >protein</td>
#       <td id="T_00455_row3_col6" class="data row3 col6" >3</td>
#       <td id="T_00455_row3_col7" class="data row3 col7" >Protein_3</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_00455_row4_col1" class="data row4 col1" >665</td>
#       <td id="T_00455_row4_col2" class="data row4 col2" >86</td>
#       <td id="T_00455_row4_col3" class="data row4 col3" >4</td>
#       <td id="T_00455_row4_col4" class="data row4 col4" >4</td>
#       <td id="T_00455_row4_col5" class="data row4 col5" >protein</td>
#       <td id="T_00455_row4_col6" class="data row4 col6" >4</td>
#       <td id="T_00455_row4_col7" class="data row4 col7" >Protein_4</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row5_col0" class="data row5 col0" >5</td>
#       <td id="T_00455_row5_col1" class="data row5 col1" >699</td>
#       <td id="T_00455_row5_col2" class="data row5 col2" >89</td>
#       <td id="T_00455_row5_col3" class="data row5 col3" >5</td>
#       <td id="T_00455_row5_col4" class="data row5 col4" >5</td>
#       <td id="T_00455_row5_col5" class="data row5 col5" >protein</td>
#       <td id="T_00455_row5_col6" class="data row5 col6" >5</td>
#       <td id="T_00455_row5_col7" class="data row5 col7" >Protein_5</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row6_col0" class="data row6 col0" >6</td>
#       <td id="T_00455_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_00455_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_00455_row6_col3" class="data row6 col3" >6</td>
#       <td id="T_00455_row6_col4" class="data row6 col4" >6</td>
#       <td id="T_00455_row6_col5" class="data row6 col5" >water</td>
#       <td id="T_00455_row6_col6" class="data row6 col6" >6</td>
#       <td id="T_00455_row6_col7" class="data row6 col7" >water</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row7_col0" class="data row7 col0" >7</td>
#       <td id="T_00455_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_00455_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_00455_row7_col3" class="data row7 col3" >6</td>
#       <td id="T_00455_row7_col4" class="data row7 col4" >7</td>
#       <td id="T_00455_row7_col5" class="data row7 col5" >water</td>
#       <td id="T_00455_row7_col6" class="data row7 col6" >6</td>
#       <td id="T_00455_row7_col7" class="data row7 col7" >water</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row8_col0" class="data row8 col0" >8</td>
#       <td id="T_00455_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_00455_row8_col2" class="data row8 col2" >1</td>
#       <td id="T_00455_row8_col3" class="data row8 col3" >6</td>
#       <td id="T_00455_row8_col4" class="data row8 col4" >8</td>
#       <td id="T_00455_row8_col5" class="data row8 col5" >water</td>
#       <td id="T_00455_row8_col6" class="data row8 col6" >6</td>
#       <td id="T_00455_row8_col7" class="data row8 col7" >water</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row9_col0" class="data row9 col0" >9</td>
#       <td id="T_00455_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_00455_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_00455_row9_col3" class="data row9 col3" >6</td>
#       <td id="T_00455_row9_col4" class="data row9 col4" >9</td>
#       <td id="T_00455_row9_col5" class="data row9 col5" >water</td>
#       <td id="T_00455_row9_col6" class="data row9 col6" >6</td>
#       <td id="T_00455_row9_col7" class="data row9 col7" >water</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row10_col0" class="data row10 col0" >10</td>
#       <td id="T_00455_row10_col1" class="data row10 col1" >1</td>
#       <td id="T_00455_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_00455_row10_col3" class="data row10 col3" >6</td>
#       <td id="T_00455_row10_col4" class="data row10 col4" >10</td>
#       <td id="T_00455_row10_col5" class="data row10 col5" >water</td>
#       <td id="T_00455_row10_col6" class="data row10 col6" >6</td>
#       <td id="T_00455_row10_col7" class="data row10 col7" >water</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row11_col0" class="data row11 col0" >11</td>
#       <td id="T_00455_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_00455_row11_col2" class="data row11 col2" >1</td>
#       <td id="T_00455_row11_col3" class="data row11 col3" >6</td>
#       <td id="T_00455_row11_col4" class="data row11 col4" >11</td>
#       <td id="T_00455_row11_col5" class="data row11 col5" >water</td>
#       <td id="T_00455_row11_col6" class="data row11 col6" >6</td>
#       <td id="T_00455_row11_col7" class="data row11 col7" >water</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row12_col0" class="data row12 col0" >12</td>
#       <td id="T_00455_row12_col1" class="data row12 col1" >1</td>
#       <td id="T_00455_row12_col2" class="data row12 col2" >1</td>
#       <td id="T_00455_row12_col3" class="data row12 col3" >6</td>
#       <td id="T_00455_row12_col4" class="data row12 col4" >12</td>
#       <td id="T_00455_row12_col5" class="data row12 col5" >water</td>
#       <td id="T_00455_row12_col6" class="data row12 col6" >6</td>
#       <td id="T_00455_row12_col7" class="data row12 col7" >water</td>
#     </tr>
#     <tr>
#       <td id="T_00455_row13_col0" class="data row13 col0" >13</td>
#       <td id="T_00455_row13_col1" class="data row13 col1" >1</td>
#       <td id="T_00455_row13_col2" class="data row13 col2" >1</td>
#       <td id="T_00455_row13_col3" class="data row13 col3" >6</td>
#       <td id="T_00455_row13_co

# %%
pdb.findMissingResidues()
pdb.findMissingAtoms()
pdb.findNonstandardResidues()

# %%
pdb.missingResidues
# Out:
# {(0, 0): ['ALA', 'GLN'],
#  (2, 0): ['ALA', 'GLN'],
#  (3, 63): ['GLU', 'ASN'],
#  (4, 0): ['LYS'],
#  (4, 62): ['GLU', 'ASN']}

# %%
pdb.nonstandardResidues

# %%
pdb.missingResidues
pdb.missingResidues = {}

# %%
pdb.missingTerminals
pdb.missingTerminals = {}

# %%
pdb.missingAtoms

# %%
msm.info(pdb, target='chain')

# %%
pdb.addMissingAtoms()

# %%
msm.info(pdb, target='chain')

# %%
pdb.findMissingResidues()
pdb.findMissingAtoms()
pdb.findNonstandardResidues()

# %%
pdb.missingAtoms

# %%
import molsysmt as msm

# %%
msm.info(pdb, target='chain')

# %%
top = pdb.topology

# %%
for bond in top.bonds():
    print(bond)
