# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Center

# %%
molecular_system = msm.systems['pentalanine']['traj_pentalanine.h5']
molecular_system = msm.convert(molecular_system, to_form='molsysmt.MolSys')

# %%
msm.info(molecular_system)
# Out:
# <style type="text/css">
# </style>
# <table id="T_2c7bf">
#   <thead>
#     <tr>
#       <th id="T_2c7bf_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_2c7bf_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_2c7bf_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_2c7bf_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_2c7bf_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_2c7bf_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_2c7bf_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_2c7bf_level0_col7" class="col_heading level0 col7" >n_peptides</th>
#       <th id="T_2c7bf_level0_col8" class="col_heading level0 col8" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2c7bf_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_2c7bf_row0_col1" class="data row0 col1" >62</td>
#       <td id="T_2c7bf_row0_col2" class="data row0 col2" >7</td>
#       <td id="T_2c7bf_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_2c7bf_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_2c7bf_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_2c7bf_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_2c7bf_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_2c7bf_row0_col8" class="data row0 col8" >5000</td>
#     </tr>
#   </tbody>
# </table>

# %%
n_structures = msm.get(molecular_system, n_structures=True)
origin = np.zeros([n_structures, 1, 3])*msm.pyunitwizard.unit('nanometers')

# %%
geometric_center = msm.structure.get_center(molecular_system)

# %%
plt.plot(geometric_center[:,0,0])
plt.plot(geometric_center[:,0,1])
plt.plot(geometric_center[:,0,2])
plt.show()
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT@uibcdf_3.10/lib/python3.10/site-packages/matplotlib/cbook.py:1345: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)

# %%
distance_before = msm.structure.get_distances(molecular_system, group_behavior='geometric center', molecular_system_2=origin)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 distance_before = msm.structure.get_distances(molecular_system, group_behavior='geometric center', molecular_system_2=origin)
#
# File ~/repos@uibcdf/MolSysMT/molsysmt/_private/digestion/digest.py:122, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     120     return func(all_args['self'], **final_args)
#     121 else:
# --> 122     return func(**final_args)
#
# TypeError: get_distances() got an unexpected keyword argument 'group_behavior'

# %%
molecular_system = msm.structure.center(molecular_system)

# %%
distance_after = msm.structure.get_distances(molecular_system, group_behavior='geometric_center',
                                             molecular_system_2=origin)

# %%
plt.plot(distance_before[:,0,0], label='Before centering')
plt.plot(distance_after[:,0,0], label='After centering')
plt.legend()
plt.show()
