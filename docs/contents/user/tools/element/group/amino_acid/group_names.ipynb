# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm

# %% [markdown]
# # Group names
#
# In construction.

# %%
msm.element.group.amino_acid.group_names
# Out:
# ['ABU',
#  'AIB',
#  'ALA',
#  'ARG',
#  'ARGN',
#  'ASH',
#  'ASN',
#  'ASN1',
#  'ASP',
#  'ASP1',
#  'ASPH',
#  'ASPP',
#  'CALA',
#  'CARG',
#  'CASN',
#  'CASP',
#  'CASPH',
#  'CCYS',
#  'CCYS2',
#  'CDAB',
#  'CGLN',
#  'CGLU',
#  'CGLUH',
#  'CGLY',
#  'CHID',
#  'CHIE',
#  'CHIP',
#  'CHISD',
#  'CHISE',
#  'CHISH',
#  'CHYP',
#  'CILE',
#  'CLEU',
#  'CLYS',
#  'CLYSN',
#  'CMET',
#  'CORN',
#  'CPHE',
#  'CPRO',
#  'CSER',
#  'CTHR',
#  'CTRP',
#  'CTYR',
#  'CVAL',
#  'CYM',
#  'CYN',
#  'CYS',
#  'CYS1',
#  'CYS2',
#  'CYSH',
#  'CYX',
#  'DAB',
#  'DALA',
#  'GLH',
#  'GLN',
#  'GLU',
#  'GLUH',
#  'GLUP',
#  'GLY',
#  'HID',
#  'HIE',
#  'HIP',
#  'HIS',
#  'HIS1',
#  'HISA',
#  'HISB',
#  'HISD',
#  'HISE',
#  'HISH',
#  'HISP',
#  'HSD',
#  'HSE',
#  'HSP',
#  'HYP',
#  'ILE',
#  'LEU',
#  'LSN',
#  'LYN',
#  'LYP',
#  'LYS',
#  'LYSH',
#  'LYSN',
#  'MELEU',
#  'MET',
#  'MEVAL',
#  'NAC',
#  'NALA',
#  'NARG',
#  'NASN',
#  'NASP',
#  'NASPH',
#  'NCYS',
# ...
