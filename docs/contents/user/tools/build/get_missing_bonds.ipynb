# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm

# %%
molsys = msm.convert(msm.demo['nglview']['md_1u19.pdb'], to_form='molsysmt.MolSys')

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_49b29">
#   <thead>
#     <tr>
#       <th id="T_49b29_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_49b29_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_49b29_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_49b29_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_49b29_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_49b29_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_49b29_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_49b29_level0_col7" class="col_heading level0 col7" >n_peptides</th>
#       <th id="T_49b29_level0_col8" class="col_heading level0 col8" >n_proteins</th>
#       <th id="T_49b29_level0_col9" class="col_heading level0 col9" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_49b29_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_49b29_row0_col1" class="data row0 col1" >5547</td>
#       <td id="T_49b29_row0_col2" class="data row0 col2" >349</td>
#       <td id="T_49b29_row0_col3" class="data row0 col3" >151</td>
#       <td id="T_49b29_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_49b29_row0_col5" class="data row0 col5" >151</td>
#       <td id="T_49b29_row0_col6" class="data row0 col6" >30</td>
#       <td id="T_49b29_row0_col7" class="data row0 col7" >27</td>
#       <td id="T_49b29_row0_col8" class="data row0 col8" >2</td>
#       <td id="T_49b29_row0_col9" class="data row0 col9" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
msm.build.get_missing_bonds(molsys, threshold='2.0 angstroms')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 msm.build.get_missing_bonds(molsys, threshold='2.0 angstroms')
#
# File ~/projects@dprada/MolSysMT/molsysmt/_private/digestion/digest.py:119, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     117     return auxiliary_output
#     118 else:
# --> 119     return func(**final_args)
#
# File ~/projects@dprada/MolSysMT/molsysmt/build/get_missing_bonds.py:30, in get_missing_bonds(molecular_system, threshold, selection, structure_indices, syntax, engine)
#      27     if old_bonds[ii][0]>old_bonds[ii][1]:
#      28         old_bonds[ii][0], old_bonds[ii][1] = old_bonds[ii][1], old_bonds[ii][0]
# ---> 30 neighbors, distance = get_neighbors(molecular_system, selection=atom_indices,
#      31                                     selection_2=atom_indices, threshold=threshold, output='dict')
#      33 for atom_i, atom_j in old_bonds:
#      34     for kk, neighbors_frame in enumerate(neighbors):
#
# File ~/projects@dprada/MolSysMT/molsysmt/_private/digestion/digest.py:119, in digest.<locals>.digestor.<locals>.wrapper(*args, **kwargs)
#     117     return auxiliary_output
#     118 else:
# --> 119     return func(**final_args)
#
# File ~/projects@dprada/MolSysMT/molsysmt/structure/get_neighbors.py:128, in get_neighbors(molecular_system, selection, groups_of_atoms, group_behavior, structure_indices, molecular_system_2, selection_2, groups_of_atoms_2, group_behavior_2, structure_indices_2, threshold, n_neighbors, atom_indices, pbc, output, engine, syntax)
#     125 aux_neighs = []
#     126 aux_dists = []
# --> 128 for kk in range(len(neighbs)):
#     130     dict_neighs = {}
#     131     dict_dists = {}
#
# NameError: name 'neighbs' is not defined
