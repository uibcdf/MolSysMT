# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Add)=
# # Add
#
# *Adding elements of a molecular system into another molecular system.*
#
# Elements coming from different molecular systems can be added to a given system with the {func}`molsysmt.basic.add` function.
#
# ## How this function works
#
# ```{admonition} API documentation
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function:{func}`molsysmt.basic.add`.
# ```
#
# Let's show how this function works with three peptides defined as three different molecular systems: proline dipeptide ($A$), valine dipeptide ($B$), and lysine dipeptide ($C$).

# %%
import molsysmt as msm

# %%
molecular_system_A = msm.build.build_peptide('AceProNme')
molecular_system_B = msm.build.build_peptide('AceValNme')
molecular_system_C = msm.build.build_peptide('AceLysNme')

# %% [markdown]
# The molecular systems $B$ and $C$ need to be translated to avoid their overlapping once their elements are added to $A$.

# %%
molecular_system_B = msm.structure.translate(molecular_system_B, translation='[-1.0, 0.0, 0.0] nanometers')
molecular_system_C = msm.structure.translate(molecular_system_C, translation='[1.0, 0.0, 0.0] nanometers')

# %% [markdown]
# Let's see how $A$ is defined before adding $B$ and $C$:

# %%
msm.info(molecular_system_A)
# Out:
# <style type="text/css">
# </style>
# <table id="T_684b9">
#   <thead>
#     <tr>
#       <th id="T_684b9_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_684b9_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_684b9_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_684b9_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_684b9_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_684b9_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_684b9_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_684b9_level0_col7" class="col_heading level0 col7" >n_peptides</th>
#       <th id="T_684b9_level0_col8" class="col_heading level0 col8" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_684b9_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_684b9_row0_col1" class="data row0 col1" >26</td>
#       <td id="T_684b9_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_684b9_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_684b9_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_684b9_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_684b9_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_684b9_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_684b9_row0_col8" class="data row0 col8" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now it is time to use {func}`molsysmt.basic.add`:

# %%
msm.add(molecular_system_A, molecular_system_B)
msm.add(molecular_system_A, molecular_system_C)

# %% [markdown]
# :::{tip}
# All methods defined in the {ref}`molsysmt.basic <API basic>` module can be invoked also from the main level of the library. Hence, {func}`molsysmt.add` is the same method as {func}`molsysmt.basic.add`.
# :::

# %% [markdown]
# Let's see now the new content of $A$:

# %%
msm.info(molecular_system_A, element='system')
# Out:
# <style type="text/css">
# </style>
# <table id="T_5d731">
#   <thead>
#     <tr>
#       <th id="T_5d731_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_5d731_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_5d731_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_5d731_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_5d731_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_5d731_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_5d731_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_5d731_level0_col7" class="col_heading level0 col7" >n_peptides</th>
#       <th id="T_5d731_level0_col8" class="col_heading level0 col8" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5d731_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_5d731_row0_col1" class="data row0 col1" >88</td>
#       <td id="T_5d731_row0_col2" class="data row0 col2" >9</td>
#       <td id="T_5d731_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_5d731_row0_col4" class="data row0 col4" >3</td>
#       <td id="T_5d731_row0_col5" class="data row0 col5" >3</td>
#       <td id="T_5d731_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_5d731_row0_col7" class="data row0 col7" >3</td>
#       <td id="T_5d731_row0_col8" class="data row0 col8" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

nglview_htmlfile = '../../../../_static/nglview/add.html'

# %%
msm.view(molecular_system_A, standard=True)
# Out:
# NGLWidget()

# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

if False:
    # to write an html the view had to be displayed in a cell before
    msm.thirds.nglview.write_html(view, nglview_htmlfile)

# %% [markdown]
# :::{seealso}
# [User guide > Tools > Build > Build peptide](../build/build_peptide.ipynb):
# [User guide > Tools > Structure > Translate](../structure/translate.ipynb):
# [User guide > Tools > Basic > Info](info.ipynb): Printing out summary information of a molecular system.
# [User guide > Tools > Basic > View](view.ipynb): Showing a molecular system.
# [User guide > Tools > Basic > Merge](merge.ipynb): Merging the elements of different molecular systems.
# :::
