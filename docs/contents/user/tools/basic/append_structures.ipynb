# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Append_structures)=
# # Append structures
#
# *Adding structures from a molecular system to another molecular system.*
#
# Structures from different molecular systems can be appended to a given system with the {func}`molsysmt.basic.append_structures` method. The number of atoms needs to be the same for all molecular systems involved in the action.
#
# ```{admonition} API documentation
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function:{func}`molsysmt.basic.append_structures`.
# ```
#
# Let's show how this method works with the alanine dipeptide defined as three diferent molecular systems with different structures.

# %%
import molsysmt as msm

# %%
molecular_system_A = msm.build.build_peptide('AceAlaNME')
molecular_system_B = msm.structure.translate(molecular_system_A, translation='[0.1, 0.1, 0.1] nanometers')
molecular_system_C = msm.structure.translate(molecular_system_A, translation='[0.2, 0.2, 0.2] nanometers')

# %% [markdown]
# Systems $B$ and $C$ were translated in space. This way all three systems have the same elements but different structures.
# Let's see how $A$ is defined before appending the structures of $B$ and $C$:

# %%
msm.info(molecular_system_A)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5b349">
#   <thead>
#     <tr>
#       <th id="T_5b349_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_5b349_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_5b349_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_5b349_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_5b349_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_5b349_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_5b349_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_5b349_level0_col7" class="col_heading level0 col7" >n_peptides</th>
#       <th id="T_5b349_level0_col8" class="col_heading level0 col8" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b349_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_5b349_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_5b349_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_5b349_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_5b349_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_5b349_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_5b349_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_5b349_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_5b349_row0_col8" class="data row0 col8" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now it is time to use {func}`molsysmt.basic.append_structures`:

# %%
msm.append_structures(molecular_system_A, molecular_system_B)
msm.append_structures(molecular_system_A, molecular_system_C)

# %% [markdown]
# :::{tip}
# All methods defined in the {ref}`molsysmt.basic <API basic>` module can be invoked also from the main level of the library. As such, {func}`molsysmt.append_structures` is the same method as {func}`molsysmt.basic.append_structures`.
# :::

# %% [markdown]
# Let's see now the new content of $A$:

# %%
msm.info(molecular_system_A)
# Out:
# <style type="text/css">
# </style>
# <table id="T_234c3">
#   <thead>
#     <tr>
#       <th id="T_234c3_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_234c3_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_234c3_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_234c3_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_234c3_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_234c3_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_234c3_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_234c3_level0_col7" class="col_heading level0 col7" >n_peptides</th>
#       <th id="T_234c3_level0_col8" class="col_heading level0 col8" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_234c3_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_234c3_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_234c3_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_234c3_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_234c3_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_234c3_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_234c3_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_234c3_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_234c3_row0_col8" class="data row0 col8" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

nglview_htmlfile = '../../../../_static/nglview/append_structures.html'

# %%
msm.view(molecular_system_A, standard=True)
# Out:
# NGLWidget(max_frame=2)

# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

if False:
    # to write an html the view had to be displayed in a cell before
    msm.thirds.nglview.write_html(view, nglview_htmlfile)

# %% [markdown]
# :::{seealso}
# [User guide > Tools > Build > Build peptide](../build/build_peptide.ipynb):
# [User guide > Tools > Structure > Translate](../structure/translate.ipynb):
# [User guide > Tools > Basic > Info](info.ipynb): Printing out summary information of a molecular system.
# [User guide > Tools > Basic > View](view.ipynb): Showing a molecular system.
# :::
