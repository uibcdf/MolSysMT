# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

static_dir = '../../../../_static/nglview/user/tools/basic/append_structures/'
nglview_htmlfiles = [
    static_dir+'append_structures.html',
] # in order of apparence

# %%
import molsysmt as msm

# %% [markdown]
# (UserGuide_Tools_Basic_Concatenate_Structures)=
# # Concatenate structures
#
# *Concatenating the structures of a molecular systems' list.*
#
# The structures of a molecular systems's list, where all of them have the same topology -they must be the same molecular system, in deed-, are concatenated. The resultant molecular system will contain all structures in the same order they were concatenated.
#
# Let's show how this method works with the alanine dipeptide defined as three diferent molecular systems with different structures.

# %%
import molsysmt as msm

# %%
molecular_system_A = msm.build.build_peptide('AceAlaNME')
molecular_system_B = msm.structure.translate(molecular_system_A, translation='[0.1, 0.1, 0.1] nanometers')
molecular_system_C = msm.structure.translate(molecular_system_A, translation='[0.2, 0.2, 0.2] nanometers')

# %%
molecular_system_D = msm.concatenate_structures([molecular_system_A, molecular_system_B, molecular_system_C])

# %% [markdown]
# ```{admonition} Tip
# :class: tip
# All methods defined in the {ref}`molsysmt.basic <API basic>` module can be invoked also from the main level of the library. As such, {func}`molsysmt.concatenate_structures` is the same method as {func}`molsysmt.basic.concatenate_structures`.
# ```

# %%
msm.info(molecular_system_D)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0825f">
#   <thead>
#     <tr>
#       <th id="T_0825f_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_0825f_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_0825f_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_0825f_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_0825f_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_0825f_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_0825f_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_0825f_level0_col7" class="col_heading level0 col7" >n_peptides</th>
#       <th id="T_0825f_level0_col8" class="col_heading level0 col8" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0825f_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#       <td id="T_0825f_row0_col1" class="data row0 col1" >22</td>
#       <td id="T_0825f_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_0825f_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_0825f_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_0825f_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_0825f_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_0825f_row0_col7" class="data row0 col7" >1</td>
#       <td id="T_0825f_row0_col8" class="data row0 col8" >3</td>
#     </tr>
#   </tbody>
# </table>

# %%
msm.view(molecular_system_D)
# Out:
# NGLWidget(max_frame=2)

# %% [markdown]
# ```{admonition} See also
# :class: attention
# {func}`molsysmt.basic.concatenate_structures`, {func}`molsysmt.build.build_peptide`, {func}`molsysmt.structure.translate`, {func}`molsysmt.basic.info`, {func}`molsysmt.basic.view`
# ```
