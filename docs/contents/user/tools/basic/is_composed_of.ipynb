# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm

# %% [markdown]
# # Is composed of

# %%
molsys = msm.convert('pdb_id:181L', to_form='molsysmt.MolSys')
# Out:
# /home/diego/projects/MolSysMT/molsysmt/item/mmtf_MMTFDecoder/to_molsysmt_Topology.py:34: UserWarning: The structure in the PDB has biological assemblies. There are geometrical transformations proposed in the structure. See the following issue in the source code repository: https://github.com/uibcdf/MolSysMT/issues/33
#   warnings.warn(warning_message)

# %%
msm.info(molsys)
# Out:
# <style type="text/css">
# </style>
# <table id="T_78c53_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >form</th>
#       <th class="col_heading level0 col1" >n_atoms</th>
#       <th class="col_heading level0 col2" >n_groups</th>
#       <th class="col_heading level0 col3" >n_components</th>
#       <th class="col_heading level0 col4" >n_chains</th>
#       <th class="col_heading level0 col5" >n_molecules</th>
#       <th class="col_heading level0 col6" >n_entities</th>
#       <th class="col_heading level0 col7" >n_waters</th>
#       <th class="col_heading level0 col8" >n_ions</th>
#       <th class="col_heading level0 col9" >n_small_molecules</th>
#       <th class="col_heading level0 col10" >n_proteins</th>
#       <th class="col_heading level0 col11" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_78c53_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
# ...

# %%
msm.is_composed_of(molsys, proteins=True)
# Out:
# False

# %%
msm.is_composed_of(molsys, proteins=True, waters=True, small_molecules=True, ions=True)
# Out:
# True

# %%
msm.is_composed_of(molsys, proteins=1, waters=True, small_molecules=2, ions=True)
# Out:
# True

# %%
molsys = msm.extract(molsys, selection='molecule_type=="protein"')

# %%
msm.is_composed_of(molsys, proteins=1)
# Out:
# True

# %%
msm.is_composed_of(molsys, proteins=1, waters=2, ions=2)
# Out:
# False
