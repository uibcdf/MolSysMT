# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

#import warnings
#warnings.filterwarnings('ignore')

# %% [markdown]
# (Tutorial_Is_a_molecular_system)=
# # Is a molecular system
#
# *Verifying the validity of a molecular system*
#
# A molecular system can be defined with a single item or with list of items. To check if a given collection of items defines, or not, a valid molecular system, the function `molsysmt.basic.is_a_molecular_system` can be used. But what does "a valid molecular system" means? It means that all items can be combined adding attributes over the same system without incompatibilities.
#
# :::{hint}
# Visit the section [User guide > Introduction > Molecular System](../../intro/molecular_systems/items.md) in case you are not familiar with the concepts of "item" in MolSysMT.
# :::
#
# ## How this function works
#
# :::{admonition} API documentation
# Follow this link for a detailed description of the input arguments, raised errors, and returned objects of this function:{func}`molsysmt.basic.is_a_molecular_system`.
# :::
#
# Let's illustrate how this function works this with an example:

# %%
import molsysmt as msm

# %%
topology = msm.systems.demo['pentalanine']['pentalanine.prmtop']
structures_A = msm.systems.demo['pentalanine']['pentalanine.inpcrd']
structures_B = msm.systems.demo['chicken villin HP35']['traj_chicken_villin_HP35_solvated.dcd']

# %% [markdown]
# We have and item, a \*.prmtop file, that per se can define a molecular system without structures:

# %%
msm.info(topology)
# Out:
# <style type="text/css">
# </style>
# <table id="T_94a4b">
#   <thead>
#     <tr>
#       <th id="T_94a4b_level0_col0" class="col_heading level0 col0" >form</th>
#       <th id="T_94a4b_level0_col1" class="col_heading level0 col1" >n_atoms</th>
#       <th id="T_94a4b_level0_col2" class="col_heading level0 col2" >n_groups</th>
#       <th id="T_94a4b_level0_col3" class="col_heading level0 col3" >n_components</th>
#       <th id="T_94a4b_level0_col4" class="col_heading level0 col4" >n_chains</th>
#       <th id="T_94a4b_level0_col5" class="col_heading level0 col5" >n_molecules</th>
#       <th id="T_94a4b_level0_col6" class="col_heading level0 col6" >n_entities</th>
#       <th id="T_94a4b_level0_col7" class="col_heading level0 col7" >n_waters</th>
#       <th id="T_94a4b_level0_col8" class="col_heading level0 col8" >n_peptides</th>
#       <th id="T_94a4b_level0_col9" class="col_heading level0 col9" >n_structures</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_94a4b_row0_col0" class="data row0 col0" >file:prmtop</td>
#       <td id="T_94a4b_row0_col1" class="data row0 col1" >5207</td>
#       <td id="T_94a4b_row0_col2" class="data row0 col2" >1722</td>
#       <td id="T_94a4b_row0_col3" class="data row0 col3" >1716</td>
#       <td id="T_94a4b_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_94a4b_row0_col5" class="data row0 col5" >1716</td>
#       <td id="T_94a4b_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_94a4b_row0_col7" class="data row0 col7" >1715</td>
#       <td id="T_94a4b_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_94a4b_row0_col9" class="data row0 col9" >None</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We also have two items, a \*.inpcrd and a \*.dcd file, that again, each one can define a molecular system with no topological attributes:

# %%
msm.info(structures_A)

# %%
msm.info(structures_B)

# %% [markdown]
# We can wonder, can the items `topology` and `structures_A` define a molecular system together?

# %%
msm.is_a_molecular_system([topology, structures_A])

# %% [markdown]
# ```{admonition} Tip
# :class: tip
# All methods defined in the {ref}`molsysmt.basic <API basic>` module can be invoked also from the main level of the library. Hence, {func}`molsysmt.is_a_molecular_system` is the same method as {func}`molsysmt.basic.is_a_molecular_system`.
# ```

# %% [markdown]
# And can the items `topology` and `structures_B` be used to define a molecular system?

# %%
msm.is_a_molecular_system([topology, structures_B])

# %% [markdown]
# ```{admonition} See also
# :class: attention
# {func}`molsysmt.basic.is_a_molecular_system`, {func}`molsysmt.basic.info`
# ```
