# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# (UserGuide_Tools_Basic_Extract)=
# # Extract
#
# *Extracting a portion of a molecular system.*
#
# The function {func}`molsysmt.basic.extract` allows to extract a part of a molecular system. It's output is a new molecular system with the elements selected by the user.
#
# Let's see {func}`molsysmt.basic.extract` in action with a simple example:

# %%
import molsysmt as msm

# %%
molecular_system = msm.convert('181L')

# %% [markdown]
# ```{admonition} Tip
# :class: tip
# The default output form of {func}`molsysmt.basic.convert` is the native `molsysmt.MolSys`.
# ```

# %%
msm.info(molecular_system, element='entity')
# Out:
# <style type="text/css">
# </style>
# <table id="T_ecc95">
#   <thead>
#     <tr>
#       <th id="T_ecc95_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_ecc95_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_ecc95_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_ecc95_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_ecc95_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_ecc95_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_ecc95_level0_col6" class="col_heading level0 col6" >n chains</th>
#       <th id="T_ecc95_level0_col7" class="col_heading level0 col7" >n molecules</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ecc95_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ecc95_row0_col1" class="data row0 col1" >T4 lysozyme</td>
#       <td id="T_ecc95_row0_col2" class="data row0 col2" >protein</td>
#       <td id="T_ecc95_row0_col3" class="data row0 col3" >1289</td>
#       <td id="T_ecc95_row0_col4" class="data row0 col4" >162</td>
#       <td id="T_ecc95_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_ecc95_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_ecc95_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ecc95_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_ecc95_row1_col1" class="data row1 col1" >Chloride ion</td>
#       <td id="T_ecc95_row1_col2" class="data row1 col2" >ion</td>
#       <td id="T_ecc95_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_ecc95_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_ecc95_row1_col5" class="data row1 col5" >2</td>
#       <td id="T_ecc95_row1_col6" class="data row1 col6" >2</td>
#       <td id="T_ecc95_row1_col7" class="data row1 col7" >2</td>
#     </tr>
#     <tr>
#       <td id="T_ecc95_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_ecc95_row2_col1" class="data row2 col1" >2-hydroxyethyl disulfide</td>
#       <td id="T_ecc95_row2_col2" class="data row2 col2" >small molecule</td>
#       <td id="T_ecc95_row2_col3" class="data row2 col3" >8</td>
#       <td id="T_ecc95_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_ecc95_row2_col5" class="data row2 col5" >1</td>
#       <td id="T_ecc95_row2_col6" class="data row2 col6" >1</td>
#       <td id="T_ecc95_row2_col7" class="data row2 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ecc95_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_ecc95_row3_col1" class="data row3 col1" >Benzene</td>
#       <td id="T_ecc95_row3_col2" class="data row3 col2" >small molecule</td>
#       <td id="T_ecc95_row3_col3" class="data row3 col3" >6</td>
#       <td id="T_ecc95_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_ecc95_row3_col5" class="data row3 col5" >1</td>
#       <td id="T_ecc95_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_ecc95_row3_col7" class="data row3 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_ecc95_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_ecc95_row4_col1" class="data row4 col1" >water</td>
#       <td id="T_ecc95_row4_col2" class="data row4 col2" >water</td>
#       <td id="T_ecc95_row4_col3" class="data row4 col3" >136</td>
#       <td id="T_ecc95_row4_col4" class="data row4 col4" >136</td>
#       <td id="T_ecc95_row4_col5" class="data row4 col5" >136</td>
#       <td id="T_ecc95_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_ecc95_row4_col7" class="data row4 col7" >136</td>
#     </tr>
#   </tbody>
# </table>

# %%
molecular_subsystem = msm.extract(molecular_system, selection='entity_name in ["T4 lysozyme", "Benzene"]')

# %% [markdown]
# ```{admonition} Tip
# :class: tip
# All methods defined in the {ref}`molsysmt.basic <API basic>` module can be invoked also from the main level of the library. Hence, {func}`molsysmt.extract` is the same method as {func}`molsysmt.basic.extract`.
# ```

# %%
msm.info(molecular_subsystem, element='entity')
# Out:
# <style type="text/css">
# </style>
# <table id="T_6e909">
#   <thead>
#     <tr>
#       <th id="T_6e909_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_6e909_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_6e909_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_6e909_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_6e909_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_6e909_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_6e909_level0_col6" class="col_heading level0 col6" >n chains</th>
#       <th id="T_6e909_level0_col7" class="col_heading level0 col7" >n molecules</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_6e909_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_6e909_row0_col1" class="data row0 col1" >T4 lysozyme</td>
#       <td id="T_6e909_row0_col2" class="data row0 col2" >protein</td>
#       <td id="T_6e909_row0_col3" class="data row0 col3" >1289</td>
#       <td id="T_6e909_row0_col4" class="data row0 col4" >162</td>
#       <td id="T_6e909_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_6e909_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_6e909_row0_col7" class="data row0 col7" >1</td>
#     </tr>
#     <tr>
#       <td id="T_6e909_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_6e909_row1_col1" class="data row1 col1" >Benzene</td>
#       <td id="T_6e909_row1_col2" class="data row1 col2" >small molecule</td>
#       <td id="T_6e909_row1_col3" class="data row1 col3" >6</td>
#       <td id="T_6e909_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_6e909_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_6e909_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_6e909_row1_col7" class="data row1 col7" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ```{admonition} See also
# :class: attention
# {func}`molsysmt.basic.extract`, {func}`molsysmt.basic.convert`, {func}`molsysmt.basic.info`
# ```
