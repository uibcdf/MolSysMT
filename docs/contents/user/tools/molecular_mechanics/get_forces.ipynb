# %%
# This cell is removed with the tag: "remove-input"
# As such, it will not be shown in documentation

#import warnings
#warnings.filterwarnings('ignore')

# %% [markdown]
# # Get forces
# *Get forces.*

# %%
import molsysmt as msm

# %%
molecular_system = msm.convert(msm.systems['Barnase-Barstar']['barnase_barstar.h5msm'])

# %%
msm.info(molecular_system, element='molecule')
# Out:
# <style type="text/css">
# </style>
# <table id="T_15bd9">
#   <thead>
#     <tr>
#       <th id="T_15bd9_level0_col0" class="col_heading level0 col0" >index</th>
#       <th id="T_15bd9_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_15bd9_level0_col2" class="col_heading level0 col2" >type</th>
#       <th id="T_15bd9_level0_col3" class="col_heading level0 col3" >n atoms</th>
#       <th id="T_15bd9_level0_col4" class="col_heading level0 col4" >n groups</th>
#       <th id="T_15bd9_level0_col5" class="col_heading level0 col5" >n components</th>
#       <th id="T_15bd9_level0_col6" class="col_heading level0 col6" >chain index</th>
#       <th id="T_15bd9_level0_col7" class="col_heading level0 col7" >entity index</th>
#       <th id="T_15bd9_level0_col8" class="col_heading level0 col8" >entity name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_15bd9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_15bd9_row0_col1" class="data row0 col1" >protein 0</td>
#       <td id="T_15bd9_row0_col2" class="data row0 col2" >protein</td>
#       <td id="T_15bd9_row0_col3" class="data row0 col3" >1727</td>
#       <td id="T_15bd9_row0_col4" class="data row0 col4" >110</td>
#       <td id="T_15bd9_row0_col5" class="data row0 col5" >1</td>
#       <td id="T_15bd9_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_15bd9_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_15bd9_row0_col8" class="data row0 col8" >protein 0</td>
#     </tr>
#     <tr>
#       <td id="T_15bd9_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_15bd9_row1_col1" class="data row1 col1" >protein 1</td>
#       <td id="T_15bd9_row1_col2" class="data row1 col2" >protein</td>
#       <td id="T_15bd9_row1_col3" class="data row1 col3" >1432</td>
#       <td id="T_15bd9_row1_col4" class="data row1 col4" >89</td>
#       <td id="T_15bd9_row1_col5" class="data row1 col5" >1</td>
#       <td id="T_15bd9_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_15bd9_row1_col7" class="data row1 col7" >1</td>
#       <td id="T_15bd9_row1_col8" class="data row1 col8" >protein 1</td>
#     </tr>
#   </tbody>
# </table>

# %%
forces = msm.molecular_mechanics.get_forces(molecular_system)

# %%
forces
# Out:
# array([[ 6.41175253e+01, -2.56125463e+01, -9.54117181e+01],
#        [ 2.91164643e+01, -6.59427567e+00,  9.10719309e+00],
#        [-9.74182186e+00,  9.26267769e+01,  1.40438808e+01],
#        ...,
#        [-9.23748627e+01,  2.88444708e+02, -4.52250654e+02],
#        [-1.42959958e+00, -1.42025676e+00, -5.30985232e-01],
#        [-2.96432525e+00, -3.03571556e-01, -2.18770036e+00]]) <Unit('kilojoule / mole / nanometer')>
