# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Center

# %%
molecular_system = msm.demo['pentalanine']['traj.h5']
molecular_system = msm.convert(molecular_system, to_form='molsysmt.MolSys')

# %%
n_structures = msm.get(molecular_system, n_structures=True)
origin = np.zeros([n_structures, 1, 3])*msm.puw.unit('nanometers')

# %%
geometric_center = msm.structure.get_geometric_center(molecular_system)

# %%
plt.plot(geometric_center[:,0,0])
plt.plot(geometric_center[:,0,1])
plt.plot(geometric_center[:,0,2])
plt.show()
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1298: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# /home/diego/Myopt/miniconda3/envs/MolSysMT/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1298: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# /home/diego/Myopt/miniconda3/envs/MolSysMT/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1298: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)

# %%
distance_before = msm.structure.get_distances(molecular_system, group_behavior='geometric_center', molecular_system_2=origin)

# %%
molecular_system = msm.structure.center(molecular_system)

# %%
distance_after = msm.structure.get_distances(molecular_system, group_behavior='geometric_center',
                                             molecular_system_2=origin)

# %%
plt.plot(distance_before[:,0,0], label='Before centering')
plt.plot(distance_after[:,0,0], label='After centering')
plt.legend()
plt.show()
# Out:
# /home/diego/Myopt/miniconda3/envs/MolSysMT/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1298: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
# /home/diego/Myopt/miniconda3/envs/MolSysMT/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:1298: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   return np.asarray(x, float)
