# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm

# %% [markdown]
# # Potential energy and energy minimization

# %% [markdown]
# ## Some examples:

# %%
molecular_system = msm.demo_systems.metenkephalin()

# %%
msm.info(molecular_system, target='group')
# Out:
# <style  type="text/css" >
# </style><table id="T_7ba45_" ><thead>    <tr>        <th class="col_heading level0 col0" >index</th>        <th class="col_heading level0 col1" >id</th>        <th class="col_heading level0 col2" >name</th>        <th class="col_heading level0 col3" >type</th>        <th class="col_heading level0 col4" >n atoms</th>        <th class="col_heading level0 col5" >component index</th>        <th class="col_heading level0 col6" >chain index</th>        <th class="col_heading level0 col7" >molecule index</th>        <th class="col_heading level0 col8" >molecule type</th>        <th class="col_heading level0 col9" >entity index</th>        <th class="col_heading level0 col10" >entity name</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7ba45_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_7ba45_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_7ba45_row0_col2" class="data row0 col2" >TYR</td>
#                         <td id="T_7ba45_row0_col3" class="data row0 col3" >aminoacid</td>
#                         <td id="T_7ba45_row0_col4" class="data row0 col4" >21</td>
#                         <td id="T_7ba45_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_7ba45_row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_7ba45_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_7ba45_row0_col8" class="data row0 col8" >peptide</td>
#                         <td id="T_7ba45_row0_col9" class="data row0 col9" >0</td>
#                         <td id="T_7ba45_row0_col10" class="data row0 col10" >Peptide_0</td>
#             </tr>
#             <tr>
#                                 <td id="T_7ba45_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_7ba45_row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_7ba45_row1_col2" class="data row1 col2" >GLY</td>
#                         <td id="T_7ba45_row1_col3" class="data row1 col3" >aminoacid</td>
#                         <td id="T_7ba45_row1_col4" class="data row1 col4" >7</td>
#                         <td id="T_7ba45_row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_7ba45_row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_7ba45_row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_7ba45_row1_col8" class="data row1 col8" >peptide</td>
#                         <td id="T_7ba45_row1_col9" class="data row1 col9" >0</td>
#                         <td id="T_7ba45_row1_col10" class="data row1 col10" >Peptide_0</td>
#             </tr>
#             <tr>
#                                 <td id="T_7ba45_row2_col0" class="data row2 col0" >2</td>
#                         <td id="T_7ba45_row2_col1" class="data row2 col1" >3</td>
#                         <td id="T_7ba45_row2_col2" class="data row2 col2" >GLY</td>
#                         <td id="T_7ba45_row2_col3" class="data row2 col3" >aminoacid</td>
#                         <td id="T_7ba45_row2_col4" class="data row2 col4" >7</td>
#                         <td id="T_7ba45_row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_7ba45_row2_col6" class="data row2 col6" >0</td>
#                         <td id="T_7ba45_row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_7ba45_row2_col8" class="data row2 col8" >peptide</td>
#                         <td id="T_7ba45_row2_col9" class="data row2 col9" >0</td>
#                         <td id="T_7ba45_row2_col10" class="data row2 col10" >Peptide_0</td>
#             </tr>
#             <tr>
#                                 <td id="T_7ba45_row3_col0" class="data row3 col0" >3</td>
#                         <td id="T_7ba45_row3_col1" class="data row3 col1" >4</td>
#                         <td id="T_7ba45_row3_col2" class="data row3 col2" >PHE</td>
#                         <td id="T_7ba45_row3_col3" class="data row3 col3" >aminoacid</td>
#                         <td id="T_7ba45_row3_col4" class="data row3 col4" >20</td>
#                         <td id="T_7ba45_row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_7ba45_row3_col6" class="data row3 col6" >0</td>
#                         <td id="T_7ba45_row3_col7" class="data row3 col7" >0</td>
#                         <td id="T_7ba45_row3_col8" class="data row3 col8" >peptide</td>
#                         <td id="T_7ba45_row3_col9" class="data row3 col9" >0</td>
#                         <td id="T_7ba45_row3_col10" class="data row3 col10" >Peptide_0</td>
#             </tr>
#             <tr>
#                                 <td id="T_7ba45_row4_col0" class="data row4 col0" >4</td>
#                         <td id="T_7ba45_row4_col1" class="data row4 col1" >5</td>
#                         <td id="T_7ba45_row4_col2" class="data row4 col2" >MET</td>
#                         <td id="T_7ba45_row4_col3" class="data row4 col3" >aminoacid</td>
#                         <td id="T_7ba45_row4_col4" class="data row4 col4" >17</td>
#                         <td id="T_7ba45_row4_col5" class="data row4 col5" >0</td>
#                         <td id="T_7ba45_row4_col6" class="data row4 col6" >0</td>
#                         <td id="T_7ba45_row4_col7" class="data row4 col7" >0</td>
#                         <td id="T_7ba45_row4_col8" class="data row4 col8" >peptide</td>
#                         <td id="T_7ba45_row4_col9" class="data row4 col9" >0</td>
#                         <td id="T_7ba45_row4_col10" class="data row4 col10" >Peptide_0</td>
#             </tr>
#     </tbody></table>

# %%
molecular_system = msm.add_terminal_capping(molecular_system, N_terminal=None, C_terminal=None)

# %%
msm.info(molecular_system)
# Out:
# <style  type="text/css" >
# </style><table id="T_a15e1_" ><thead>    <tr>        <th class="col_heading level0 col0" >form</th>        <th class="col_heading level0 col1" >n_atoms</th>        <th class="col_heading level0 col2" >n_groups</th>        <th class="col_heading level0 col3" >n_components</th>        <th class="col_heading level0 col4" >n_chains</th>        <th class="col_heading level0 col5" >n_molecules</th>        <th class="col_heading level0 col6" >n_entities</th>        <th class="col_heading level0 col7" >n_peptides</th>        <th class="col_heading level0 col8" >n_frames</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a15e1_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#                         <td id="T_a15e1_row0_col1" class="data row0 col1" >75</td>
#                         <td id="T_a15e1_row0_col2" class="data row0 col2" >5</td>
#                         <td id="T_a15e1_row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_a15e1_row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_a15e1_row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_a15e1_row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_a15e1_row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_a15e1_row0_col8" class="data row0 col8" >1</td>
#             </tr>
#     </tbody></table>

# %%
msm.potential_energy([molecular_system, {'forcefield':'AMBER99SBILDN'}])
# Out:
# 141066.95297981886 <Unit('kilojoule / mole')>

# %%
msm.potential_energy([molecular_system, {'forcefield':'AMBER14'}])
# Out:
# 141087.37122116212 <Unit('kilojoule / mole')>

# %%
molecular_system_min = msm.energy_minimization([molecular_system, {'forcefield':'AMBER14'}])
# Out:
# Potential Energy before minimization: 141087.37122116212 kilojoule / mole
# Potential Energy after minimization: -174.37502227177697 kilojoule / mole
