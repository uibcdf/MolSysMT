# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
from matplotlib import pyplot as plt
import simtk.unit as unit
import seaborn as sns
import numpy as np
# Out:
# _ColormakerRegistry()

# %%
#molecular_system_a = msm.convert('mmtf:2GDL', 'molsysmt.MolSys')
#molecular_system_b = msm.convert('pdb:2GDL', 'molsysmt.MolSys')
#mmtf = msm.convert('pdb:2GDL', 'mmtf.MMTFDecoder')

# %%
molecular_system = msm.test_systems.files['trp-cage_solvated.pdb']

# %%
molecular_system = msm.convert(molecular_system)

# %%
msm.info(molecular_system)
# Out:
# <style  type="text/css" >
# </style><table id="T_7bb974cc_a1a6_11ea_8791_fd7799d8ec5d" ><thead>    <tr>        <th class="col_heading level0 col0" >form</th>        <th class="col_heading level0 col1" >n atoms</th>        <th class="col_heading level0 col2" >n groups</th>        <th class="col_heading level0 col3" >n components</th>        <th class="col_heading level0 col4" >n chains</th>        <th class="col_heading level0 col5" >n molecules</th>        <th class="col_heading level0 col6" >n entities</th>        <th class="col_heading level0 col7" >n frames</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7bb974cc_a1a6_11ea_8791_fd7799d8ec5drow0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#                         <td id="T_7bb974cc_a1a6_11ea_8791_fd7799d8ec5drow0_col1" class="data row0 col1" >10544</td>
#                         <td id="T_7bb974cc_a1a6_11ea_8791_fd7799d8ec5drow0_col2" class="data row0 col2" >3434</td>
#                         <td id="T_7bb974cc_a1a6_11ea_8791_fd7799d8ec5drow0_col3" class="data row0 col3" >3415</td>
#                         <td id="T_7bb974cc_a1a6_11ea_8791_fd7799d8ec5drow0_col4" class="data row0 col4" >1</td>
#                         <td id="T_7bb974cc_a1a6_11ea_8791_fd7799d8ec5drow0_col5" class="data row0 col5" >1</td>
#                         <td id="T_7bb974cc_a1a6_11ea_8791_fd7799d8ec5drow0_col6" class="data row0 col6" >1</td>
#                         <td id="T_7bb974cc_a1a6_11ea_8791_fd7799d8ec5drow0_col7" class="data row0 col7" >1</td>
#             </tr>
#     </tbody></table>

# %%
aa=msm.get(molecular_system, target='atom', group_name=True)

# %%
aa = msm.get(molecular_system, target='group', type=True)

# %%
aa='water'

# %%
aa.copy()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-589c8d12b6a1> in <module>
# ----> 1 aa.copy()
#
# AttributeError: 'str' object has no attribute 'copy'

# %%
bb='TYR'

# %%
bb.__iter__
# Out:
# <method-wrapper '__iter__' of str object at 0x7fb821f5c330>

# %%
list(map(msm.elements.group.name_to_type, aa))
# Out:
# ['aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'aminoacid',
#  'ion',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  'water',
#  ...]
