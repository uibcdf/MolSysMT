# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molsysmt as msm
from molsysmt import puw

# %% [markdown]
# # Add and Merge

# %% [markdown]
# ## Adding to a molecular system

# %% [markdown]
# Atoms or elements coming from different molecular systems can be added to a given system:

# %%
molecular_system_1 = msm.build_peptide(['AceProNme',{'forcefield':'AMBER14', 'implicit_solvent':'OBC1'}])
molecular_system_2 = msm.build_peptide(['AceValNme',{'forcefield':'AMBER14', 'implicit_solvent':'OBC1'}])
molecular_system_3 = msm.build_peptide(['AceLysNme',{'forcefield':'AMBER14', 'implicit_solvent':'OBC1'}])

# %%
msm.translate(molecular_system_2, translation=[-1.0, 0.0, 0.0]*puw.unit('nm'))
msm.translate(molecular_system_3, translation=[1.0, 0.0, 0.0]*puw.unit('nm'))

# %%
msm.info(molecular_system_1)
# Out:
# <style  type="text/css" >
# </style><table id="T_0fffc_" ><thead>    <tr>        <th class="col_heading level0 col0" >form</th>        <th class="col_heading level0 col1" >n_atoms</th>        <th class="col_heading level0 col2" >n_groups</th>        <th class="col_heading level0 col3" >n_components</th>        <th class="col_heading level0 col4" >n_chains</th>        <th class="col_heading level0 col5" >n_molecules</th>        <th class="col_heading level0 col6" >n_entities</th>        <th class="col_heading level0 col7" >n_peptides</th>        <th class="col_heading level0 col8" >n_frames</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0fffc_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#                         <td id="T_0fffc_row0_col1" class="data row0 col1" >26</td>
#                         <td id="T_0fffc_row0_col2" class="data row0 col2" >3</td>
#                         <td id="T_0fffc_row0_col3" class="data row0 col3" >1</td>
#                         <td id="T_0fffc_row0_col4" class="data row0 col4" >1</td>
#                         <td id="T_0fffc_row0_col5" class="data row0 col5" >1</td>
#                         <td id="T_0fffc_row0_col6" class="data row0 col6" >1</td>
#                         <td id="T_0fffc_row0_col7" class="data row0 col7" >1</td>
#                         <td id="T_0fffc_row0_col8" class="data row0 col8" >1</td>
#             </tr>
#     </tbody></table>

# %%
msm.add(molecular_system_1, [molecular_system_2, molecular_system_3])

# %%
msm.info(molecular_system_1)
# Out:
# <style  type="text/css" >
# </style><table id="T_e8100_" ><thead>    <tr>        <th class="col_heading level0 col0" >form</th>        <th class="col_heading level0 col1" >n_atoms</th>        <th class="col_heading level0 col2" >n_groups</th>        <th class="col_heading level0 col3" >n_components</th>        <th class="col_heading level0 col4" >n_chains</th>        <th class="col_heading level0 col5" >n_molecules</th>        <th class="col_heading level0 col6" >n_entities</th>        <th class="col_heading level0 col7" >n_peptides</th>        <th class="col_heading level0 col8" >n_frames</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_e8100_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#                         <td id="T_e8100_row0_col1" class="data row0 col1" >88</td>
#                         <td id="T_e8100_row0_col2" class="data row0 col2" >9</td>
#                         <td id="T_e8100_row0_col3" class="data row0 col3" >3</td>
#                         <td id="T_e8100_row0_col4" class="data row0 col4" >3</td>
#                         <td id="T_e8100_row0_col5" class="data row0 col5" >3</td>
#                         <td id="T_e8100_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_e8100_row0_col7" class="data row0 col7" >3</td>
#                         <td id="T_e8100_row0_col8" class="data row0 col8" >1</td>
#             </tr>
#     </tbody></table>

# %%
msm.view(molecular_system_1)
# Out:
# NGLWidget()

# %% [markdown]
# **Implementar o Checar**: Que pasa si quiero por ejemplo hacer merge de varios sistemas moleculares descritos por varios items? Por ejemplo:
#
# msm.add([a.prmtop, a.inpcrd], [[b.prmtop, b.inpcrd], [c.prmtop, b.inpcrd]])

# %% [markdown]
# ## Merging molecular systems

# %% [markdown]
# A list of molecular systems are merged in to a new molecular system:

# %%
molecular_system_1 = msm.build_peptide(['AceProNme',{'forcefield':'AMBER14', 'implicit_solvent':'OBC1'}])
molecular_system_2 = msm.build_peptide(['AceValNme',{'forcefield':'AMBER14', 'implicit_solvent':'OBC1'}])
molecular_system_3 = msm.build_peptide(['AceLysNme',{'forcefield':'AMBER14', 'implicit_solvent':'OBC1'}])

# %%
msm.translate(molecular_system_2, translation=[-1.0, 0.0, 0.0]*puw.unit('nm'))
msm.translate(molecular_system_3, translation=[1.0, 0.0, 0.0]*puw.unit('nm'))

# %%
molecular_system_total = msm.merge([molecular_system_1, molecular_system_2, molecular_system_3])

# %%
msm.info(molecular_system_total)
# Out:
# <style  type="text/css" >
# </style><table id="T_7b0a2_" ><thead>    <tr>        <th class="col_heading level0 col0" >form</th>        <th class="col_heading level0 col1" >n_atoms</th>        <th class="col_heading level0 col2" >n_groups</th>        <th class="col_heading level0 col3" >n_components</th>        <th class="col_heading level0 col4" >n_chains</th>        <th class="col_heading level0 col5" >n_molecules</th>        <th class="col_heading level0 col6" >n_entities</th>        <th class="col_heading level0 col7" >n_peptides</th>        <th class="col_heading level0 col8" >n_frames</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7b0a2_row0_col0" class="data row0 col0" >molsysmt.MolSys</td>
#                         <td id="T_7b0a2_row0_col1" class="data row0 col1" >88</td>
#                         <td id="T_7b0a2_row0_col2" class="data row0 col2" >9</td>
#                         <td id="T_7b0a2_row0_col3" class="data row0 col3" >3</td>
#                         <td id="T_7b0a2_row0_col4" class="data row0 col4" >3</td>
#                         <td id="T_7b0a2_row0_col5" class="data row0 col5" >3</td>
#                         <td id="T_7b0a2_row0_col6" class="data row0 col6" >3</td>
#                         <td id="T_7b0a2_row0_col7" class="data row0 col7" >3</td>
#                         <td id="T_7b0a2_row0_col8" class="data row0 col8" >1</td>
#             </tr>
#     </tbody></table>

# %%
msm.view(molecular_system_total)
# Out:
# NGLWidget()

# %% [markdown]
# **Implementar o Checar**: Que pasa si quiero por ejemplo hacer merge de varios sistemas moleculares descritos por varios items? Por ejemplo:
#
# msm.merge([[a.prmtop, a.inpcrd], [b.prmtop, b.inpcrd], [c.prmtop, c.inpcrd]])
#
# o
#
# msm.merge([[a.msm.topology, a.msm.trajectory], [b.msm.topology, b.msm.trajectory], [c.msm.topology, c.msm.trajectory]])
