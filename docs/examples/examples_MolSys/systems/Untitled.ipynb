# %%
import molsyssak as molsys
import moldynsak as moldyn
# Out:
# /home/diego/Myopt/Miniconda/miniconda3/envs/UIBCDFLab_dev/lib/python3.6/site-packages/MDAnalysis/due.py:88: UserWarning: No module named 'mock'
#   warnings.warn(str(err))

# %%
sss=molsys.fetch_pdb('2bhl','pdbfixer')

# %%
ddd=molsys.convert(sss,'mdtraj')

# %%
# Out:
# pdbfixer.pdbfixer.PDBFixer

# %%
# Out:
# mdtraj.core.trajectory.Trajectory
