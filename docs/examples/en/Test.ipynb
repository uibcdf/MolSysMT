# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molmodmt as m3t
# Out:
# /home/diego/Myopt/miniconda3/envs/UIBCDF_lab_dev/lib/python3.7/site-packages/yank/experiment.py:1170: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """)
# _ColormakerRegistry()

# %%
#molmod_test = m3t.load('1brs.pdb', to_form='mdtraj.Trajectory')
#m3t.convert('mmtf:1tcd', '1tcd.mmtf')

# %%
aa = m3t.convert('1tcd.pdb', 'mdtraj.Trajectory')

# %%
bb = m3t.convert(aa, 'molmodmt.DataFrame')

# %%
bb
# Out:
#       atom.index atom.name  atom.id atom.type atom.element  group.index  \
# 0              0         N        1         N            N            0
# 1              1        CA        2         C            C            0
# 2              2         C        3         C            C            0
# 3              3         O        4         O            O            0
# 4              4        CB        5         C            C            0
# ...          ...       ...      ...       ...          ...          ...
# 3978        3978         O     3981         O            O          657
# 3979        3979         O     3982         O            O          658
# 3980        3980         O     3983         O            O          659
# 3981        3981         O     3984         O            O          660
# 3982        3982         O     3985         O            O          661
#
#      group.name  group.id group.type component.index  ... molecule.id  \
# ...

# %%
atom = aa.topology.atom(0)

# %%
chain = aa.topology.chain(0)

# %%
chain.index
# Out:
# 0

# %%
bb
# Out:
#       atom.index atom.name  atom.id atom.type atom.element  group.index  \
# 0              0         N        1         N            N            0
# 1              1        CA        2         C            C            0
# 2              2         C        3         C            C            0
# 3              3         O        4         O            O            0
# 4              4        CB        5         C            C            0
# ...          ...       ...      ...       ...          ...          ...
# 3978        3978         O     3981         O            O          657
# 3979        3979         O     3982         O            O          658
# 3980        3980         O     3983         O            O          659
# 3981        3981         O     3984         O            O          660
# 3982        3982         O     3985         O            O          661
#
#      group.name  group.id group.type component.index  ... molecule.id  \
# ...

# %%
cc, bonds = aa.topology.to_dataframe()

# %%
help(aa.topology.atom(0))
# Out:
# Help on Atom in module mdtraj.core.topology object:
#
# class Atom(builtins.object)
#  |  Atom(name, element, index, residue, serial=None)
#  |
#  |  An Atom object represents a residue within a Topology.
#  |
#  |  Attributes
#  |  ----------
#  |  name : str
#  |      The name of the Atom
#  |  element : mdtraj.element.Element
#  |      The element of the Atoms
#  |  index : int
#  |      The index of the Atom within its Topology
#  |  residue : mdtraj.topology.Residue
#  |      The Residue this Atom belongs to
#  |  serial : int
#  |      The serial number from the PDB specification. Unlike index,
#  |      this may not be contiguous or 0-indexed.
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |      Check whether two Atom objects are equal.
#  |
#  |  __hash__(self)
#  |      A quick comparison.
#  |
#  |  __init__(self, name, element, index, residue, serial=None)
# ...

# %%
cc
# Out:
#       serial name element  resSeq resName  chainID segmentID
# 0          1    N       N       4     LYS        0
# 1          2   CA       C       4     LYS        0
# 2          3    C       C       4     LYS        0
# 3          4    O       O       4     LYS        0
# 4          5   CB       C       4     LYS        0
# ...      ...  ...     ...     ...     ...      ...       ...
# 3978    3981    O       O     339     HOH        3
# 3979    3982    O       O     340     HOH        3
# 3980    3983    O       O     341     HOH        3
# 3981    3984    O       O     342     HOH        3
# 3982    3985    O       O     343     HOH        3
#
# [3983 rows x 7 columns]

# %%
from mmtf import parse

# %%
parse('1tcd.pdb')
# Out:
# ---------------------------------------------------------------------------
# ExtraData                                 Traceback (most recent call last)
# <ipython-input-62-a335793cc8a2> in <module>
# ----> 1 parse('1tcd.pdb')
#
# ~/Myopt/miniconda3/envs/UIBCDF_lab_dev/lib/python3.7/site-packages/mmtf/api/default_api.py in parse(file_path)
#      92     newDecoder = MMTFDecoder()
#      93     with open(file_path, "rb") as fh:
# ---> 94         newDecoder.decode_data(_unpack(fh))
#      95     return newDecoder
#      96
#
# ~/Myopt/miniconda3/envs/UIBCDF_lab_dev/lib/python3.7/site-packages/mmtf/api/default_api.py in _unpack(data)
#      72
#      73 def _unpack(data):
# ---> 74     out_data = msgpack.unpackb(data.read(), raw=False)
#      75     return out_data
#      76
#
# msgpack/_unpacker.pyx in msgpack._cmsgpack.unpackb()
#
# ExtraData: unpack(b) received extra data.
