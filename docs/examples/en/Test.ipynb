# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molmodmt as m3t
# Out:
# /home/diego/Myopt/miniconda3/envs/UIBCDF_lab_dev/lib/python3.7/site-packages/yank/experiment.py:1170: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """)
# _ColormakerRegistry()

# %%
#molmod_test = m3t.load('1brs.pdb', to_form='mdtraj.Trajectory')

# %%
#m3t.convert('mmtf:1tcd', '1tcd.mmtf')

# %%
molmod_test = m3t.load('1tcd.mmtf')

# %%
m3t.get(molmod_test, n_small_molecules=True)
# Out:
# 0

# %%
m3t.info(molmod_test)
# Out:
#               form  atoms  groups  components  chains  molecules  entities  \
# 0  molmodmt.MolMod   3983     662         167       4        166         2
#
#    waters  proteins  frames
# 0     165         1       1

# %%
molmod_test.composition._dataframe.query('atom_element == ["N","O"]')
# Out:
#       atom_index atom_name  atom_id atom_type atom_element  group_index  \
# 0              0         N        1         N            N            0
# 3              3         O        4         O            O            0
# 8              8        NZ        9        NZ            N            0
# 9              9         N       10         N            N            1
# 12            12         O       13         O            O            1
# ...          ...       ...      ...       ...          ...          ...
# 3978        3978         O     3979         O            O          657
# 3979        3979         O     3980         O            O          658
# 3980        3980         O     3981         O            O          659
# 3981        3981         O     3982         O            O          660
# 3982        3982         O     3983         O            O          661
#
#      group_name  group_id group_type  component_index  ... molecule_id  \
# 0           LYS         4  aminoacid                0  ...        None
# 3           LYS         4  aminoacid                0  ...        None
# 8           LYS         4  aminoacid                0  ...        None
# 9           PRO         5  aminoacid                0  ...        None
# 12          PRO         5  aminoacid                0  ...        None
# ...         ...       ...        ...              ...  ...         ...
# 3978        HOH       339      water              162  ...        None
# 3979        HOH       340      water              163  ...        None
# 3980        HOH       341      water              164  ...        None
# 3981        HOH       342      water              165  ...        None
# 3982        HOH       343      water              166  ...        None
#
#      molecule_type entity_index                entity_name entity_id  \
# 0          protein            0  TRIOSEPHOSPHATE ISOMERASE      None
# 3          protein            0  TRIOSEPHOSPHATE ISOMERASE      None
# 8          protein            0  TRIOSEPHOSPHATE ISOMERASE      None
# 9          protein            0  TRIOSEPHOSPHATE ISOMERASE      None
# 12         protein            0  TRIOSEPHOSPHATE ISOMERASE      None
# ...            ...          ...                        ...       ...
# 3978         water            1                      water      None
# 3979         water            1                      water      None
# 3980         water            1                      water      None
# 3981         water            1                      water      None
# 3982         water            1                      water      None
#
#      entity_type bioassembly_index  bioassembly_name bioassembly_id  \
# 0        protein                 0                 1           None
# 3        protein                 0                 1           None
# 8        protein                 0                 1           None
# 9        protein                 0                 1           None
# 12       protein                 0                 1           None
# ...          ...               ...               ...            ...
# 3978       water                 0                 1           None
# 3979       water                 0                 1           None
# 3980       water                 0                 1           None
# 3981       water                 0                 1           None
# 3982       water                 0                 1           None
#
#      bioassembly_type
# 0                None
# 3                None
# 8                None
# 9                None
# 12               None
# ...               ...
# 3978             None
# 3979             None
# 3980             None
# 3981             None
# 3982             None
#
# [1544 rows x 29 columns]

# %%
lista = [0,1,2]

# %%
molmod_test.composition._dataframe.query('atom_index == @lista')
# Out:
#    atom_index atom_name  atom_id atom_type atom_element  group_index  \
# 0           0         N        1         N            N            0
# 1           1        CA        2        CA            C            0
# 2           2         C        3         C            C            0
#
#   group_name  group_id group_type  component_index  ... molecule_id  \
# 0        LYS         4  aminoacid                0  ...        None
# 1        LYS         4  aminoacid                0  ...        None
# 2        LYS         4  aminoacid                0  ...        None
#
#   molecule_type entity_index                entity_name entity_id entity_type  \
# 0       protein            0  TRIOSEPHOSPHATE ISOMERASE      None     protein
# 1       protein            0  TRIOSEPHOSPHATE ISOMERASE      None     protein
# 2       protein            0  TRIOSEPHOSPHATE ISOMERASE      None     protein
#
#   bioassembly_index  bioassembly_name bioassembly_id bioassembly_type
# 0                 0                 1           None             None
# 1                 0                 1           None             None
# 2                 0                 1           None             None
#
# [3 rows x 29 columns]

# %%
m3t.select(molmod_test, 'atom.index == @lista')
# Out:
# hola
# <frame at 0x7fd73ad505c0, file '/home/diego/Projects/MolModMT/molmodmt/forms/classes/api_molmodmt_Composition.py', line 90, code select_with_Pandas>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-91-f5df6241694f> in <module>
# ----> 1 m3t.select(molmod_test, 'atom.index == @lista')
#
# ~/Projects/MolModMT/molmodmt/multitool.py in select(item, selection, syntaxis)
#     145         else:
#     146             selection, syntaxis = _digest_selection(selection, syntaxis)
# --> 147             atom_indices = _dict_selector[form_in][syntaxis](item, selection)
#     148     elif type(selection) in [int, _int64, _int]:
#     149         atom_indices = _array([selection], dtype='int64')
#
# ~/Projects/MolModMT/molmodmt/forms/classes/api_molmodmt_MolMod.py in select_with_Pandas(item, selection)
#      79
#      80     from .api_molmodmt_Composition import select_with_Pandas as select_Composition_with_Pandas
# ---> 81     return select_Composition_with_Pandas(item.composition, selection)
#      82
#      83 def extract_subsystem(item, atom_indices='all', frame_indices='all'):
#
# ~/Projects/MolModMT/molmodmt/forms/classes/api_molmodmt_Composition.py in select_with_Pandas(item, selection)
#      88
#      89     from molmodmt.native.selector import dataframe_select
# ---> 90     atom_indices = dataframe_select(item._dataframe, selection)
#      91     return atom_indices
#      92
#
# ~/Projects/MolModMT/molmodmt/native/selector.py in dataframe_select(item, selection)
#      20     print("hola")
#      21     print(inspect.stack()[1][0])
# ---> 22     print(inspect.stack()[1][0].f_globals['lista'])
#      23
#      24     parsed_selection = parse(selection)
#
# KeyError: 'lista'

# %%
lista='patata'

# %%
from inspect import currentframe
currentframe(1).f_globals[variable]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-a32087bd1f5e> in <module>
#       1 from inspect import currentframe
# ----> 2 currentframe(1).f_globals[variable] = name
#
# NameError: name 'name' is not defined

# %%
def get_var(name):
    import inspect
    print(inspect.stack()[1][0].f_globals[name])
    #print(globals().keys())

def get_get_var(name):
    get_var(name)

# %%
get_get_var('lista')
# Out:
# patata

# %%
getouterframes(frame, context=1)
