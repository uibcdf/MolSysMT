# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import moldynmt as mdmt
import molsysmt as msmt
from matplotlib import pyplot as plt
# Out:
# /home/diego/Myopt/Miniconda/miniconda3/envs/UIBCDFLab_dev/lib/python3.6/site-packages/MDAnalysis/due.py:88: UserWarning: No module named 'duecredit'
#   warnings.warn(str(err))

# %%
receptor_ligand_traj_file=os.path.join(mdmt.utils.path_examples,'t4-lysozyme_p-xylene.h5')

# %%
traj = mdmt.load(receptor_ligand_traj_file)

# %%
mdmt.get_form(traj)
# Out:
# 'native.Native'

# %%
mdmt.info(traj)
# Out:
# Trajectory with 101 frames and 2621 atoms.

# %%
mdmt.view(traj)
# Out:
# NGLWidget(count=101)

# %%
mdmt.least_rmsd_fit(traj, ref_frame=0, selection='name CA')

# %%
mdmt.view(traj)
# Out:
# NGLWidget(count=101)

# %%
rmsd = mdmt.least_rmsd(traj, ref_frame=0, selection='name CA')

# %%
plt.plot(rmsd)
plt.title("Protein's CAs RMSD")
plt.ylabel("RMSD")
plt.xlabel("Index of Frame")
plt.show()
