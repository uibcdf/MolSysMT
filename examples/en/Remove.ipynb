# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Remove

# %%
import molsysmt as m3t

# %%
molsys = m3t.load('1tcd.mmtf')

# %%
m3t.get(molsys, target='atom', n_waters=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-6bd0e0ce5d2d> in <module>
# ----> 1 m3t.get(molsys, target='atom', n_waters=True)
#
# ~/Proyectos/MolSysMT/molsysmt/multitool.py in get(item, target, indices, selection, frame_indices, syntaxis, **kwargs)
#     614     results = []
#     615     for attribute in attributes:
# --> 616         result = _dict_get[form_in][target][attribute](item, indices=indices, frame_indices=frame_indices)
#     617         results.append(result)
#     618
#
# ~/Proyectos/MolSysMT/molsysmt/forms/classes/api_molsysmt_MolSys.py in get_n_waters_from_atom(item, indices, frame_indices)
#     167
#     168     from .api_molsysmt_Composition import get_n_waters_from_atom as _get
# --> 169     return _get(item.composition, indices=indices, frame_indices=frame_indices)
#     170
# ...

# %%
m3t.info(molsys)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-5ed631c01aa2> in <module>
# ----> 1 m3t.info(molsys)
#
# ~/Proyectos/MolSysMT/molsysmt/multitool.py in info(item, target, indices, selection, syntaxis)
#     467         n_ions, n_waters, n_cosolutes, n_small_molecules, n_peptides, n_proteins, n_dnas, n_rnas = get(item, target=target,
#     468                 n_ions=True, n_waters=True, n_cosolutes=True, n_small_molecules=True, n_peptides=True, n_proteins=True,
# --> 469                 n_dnas=True, n_rnas=True)
#     470
#     471         n_frames = get(item, target=target, n_frames=True)
#
# ~/Proyectos/MolSysMT/molsysmt/multitool.py in get(item, target, indices, selection, frame_indices, syntaxis, **kwargs)
#     614     results = []
#     615     for attribute in attributes:
# ...
