# %%
from molmodmt.forms.files.api_mmtf import to_mmtf_MMTFDecoder
from molmodmt.native import DataFrame
import pandas as pd
import numpy as np
# Out:
# _ColormakerRegistry()

# %%
df = DataFrame()

# %%
mmtf = to_mmtf_MMTFDecoder('1tcd.mmtf')

# %%
mmtf.num_atoms
# Out:
# 3983

# %%
df['atom.index']=np.arange(mmtf.num_atoms)

# %%
df
# Out:
#       atom.index atom.name atom.id atom.type atom.bonded_atom_indices  \
# 0              0       NaN     NaN       NaN                      NaN
# 1              1       NaN     NaN       NaN                      NaN
# 2              2       NaN     NaN       NaN                      NaN
# 3              3       NaN     NaN       NaN                      NaN
# 4              4       NaN     NaN       NaN                      NaN
# ...          ...       ...     ...       ...                      ...
# 3978        3978       NaN     NaN       NaN                      NaN
# 3979        3979       NaN     NaN       NaN                      NaN
# 3980        3980       NaN     NaN       NaN                      NaN
# 3981        3981       NaN     NaN       NaN                      NaN
# 3982        3982       NaN     NaN       NaN                      NaN
#
#      group.index group.name group.id group.type component.index  ...  \
# ...

# %%
df.at[3,['atom.id','atom.name']]=[666,'patata']

# %%
df
# Out:
#       atom.index atom.name atom.id atom.type atom.bonded_atom_indices  \
# 0              0       NaN     NaN       NaN                      NaN
# 1              1       NaN     NaN       NaN                      NaN
# 2              2       NaN     NaN       NaN                      NaN
# 3              3    patata     666       NaN                      NaN
# 4              4       NaN     NaN       NaN                      NaN
# ...          ...       ...     ...       ...                      ...
# 3978        3978       NaN     NaN       NaN                      NaN
# 3979        3979       NaN     NaN       NaN                      NaN
# 3980        3980       NaN     NaN       NaN                      NaN
# 3981        3981       NaN     NaN       NaN                      NaN
# 3982        3982       NaN     NaN       NaN                      NaN
#
#      group.index group.name group.id group.type component.index  ...  \
# ...

# %%
from networkx import empty_graph

# %%
G = empty_graph(100)

# %%
G.add_edge(1,3)

# %%
np.array(list(G.neighbors(3)))
# Out:
# array([0, 1])
