# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molmodmt as m3t
from molmodmt.forms.files.api_mmtf import to_mmtf_MMTFDecoder
from molmodmt.native import DataFrame
import pandas as pd
import numpy as np
# Out:
# _ColormakerRegistry()

# %%
dataframe_mmtf = m3t.convert('1tcd.mmtf', 'molmodmt.DataFrame')

# %%
#dataframe_pdb = m3t.convert('1tcd.pdb', 'molmodmt.DataFrame')

# %%
openmm_topology = m3t.convert('1tcd.pdb', to_form='openmm.Topology')

# %%
dataframe = m3t.convert(openmm_topology, 'molmodmt.DataFrame')

# %%
dataframe_mmtf
# Out:
#       atom.index atom.name  atom.id atom.type atom.bonded_atom_indices  \
# 0              0         N        1         N                      [1]
# 1              1        CA        2         C                [0, 2, 4]
# 2              2         C        3         C                [1, 3, 9]
# 3              3         O        4         O                      [2]
# 4              4        CB        5         C                   [1, 5]
# ...          ...       ...      ...       ...                      ...
# 3978        3978         O     3979         O                       []
# 3979        3979         O     3980         O                       []
# 3980        3980         O     3981         O                       []
# 3981        3981         O     3982         O                       []
# 3982        3982         O     3983         O                       []
#
#       group.index group.name  group.id group.type  component.index  ...  \
# 0               0        LYS         4  aminoacid                0  ...
# 1               0        LYS         4  aminoacid                0  ...
# 2               0        LYS         4  aminoacid                0  ...
# 3               0        LYS         4  aminoacid                0  ...
# 4               0        LYS         4  aminoacid                0  ...
# ...           ...        ...       ...        ...              ...  ...
# 3978          657        HOH       339      water              162  ...
# 3979          658        HOH       340      water              163  ...
# 3980          659        HOH       341      water              164  ...
# 3981          660        HOH       342      water              165  ...
# 3982          661        HOH       343      water              166  ...
#
#      molecule.id molecule.type entity.index                entity.name  \
# 0            NaN       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 1            NaN       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 2            NaN       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 3            NaN       protein            0  TRIOSEPHOSPHATE ISOMERASE
# 4            NaN       protein            0  TRIOSEPHOSPHATE ISOMERASE
# ...          ...           ...          ...                        ...
# 3978         NaN         water            1                      water
# 3979         NaN         water            1                      water
# 3980         NaN         water            1                      water
# 3981         NaN         water            1                      water
# 3982         NaN         water            1                      water
#
#      entity.id entity.type bioassembly.index  bioassembly.name bioassembly.id  \
# 0          NaN     protein                 0                 1            NaN
# 1          NaN     protein                 0                 1            NaN
# 2          NaN     protein                 0                 1            NaN
# 3          NaN     protein                 0                 1            NaN
# 4          NaN     protein                 0                 1            NaN
# ...        ...         ...               ...               ...            ...
# 3978       NaN       water                 0                 1            NaN
# 3979       NaN       water                 0                 1            NaN
# 3980       NaN       water                 0                 1            NaN
# 3981       NaN       water                 0                 1            NaN
# 3982       NaN       water                 0                 1            NaN
#
#      bioassembly.type
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 3978              NaN
# 3979              NaN
# 3980              NaN
# 3981              NaN
# 3982              NaN
#
# [3983 rows x 29 columns]

# %%
dataframe
# Out:
#       atom.index atom.name  atom.id atom.type atom.bonded_atom_indices  \
# 0              0         N        1         N                      [1]
# 1              1        CA        2         C                [0, 2, 4]
# 2              2         C        3         C                [1, 3, 9]
# 3              3         O        4         O                      [2]
# 4              4        CB        5         C                   [1, 5]
# ...          ...       ...      ...       ...                      ...
# 3978        3978         O     3981         O                       []
# 3979        3979         O     3982         O                       []
# 3980        3980         O     3983         O                       []
# 3981        3981         O     3984         O                       []
# 3982        3982         O     3985         O                       []
#
#       group.index group.name  group.id group.type  component.index  ...  \
# 0               0        LYS         4  aminoacid                0  ...
# 1               0        LYS         4  aminoacid                0  ...
# 2               0        LYS         4  aminoacid                0  ...
# 3               0        LYS         4  aminoacid                0  ...
# 4               0        LYS         4  aminoacid                0  ...
# ...           ...        ...       ...        ...              ...  ...
# 3978          657        HOH       339      water              162  ...
# 3979          658        HOH       340      water              163  ...
# 3980          659        HOH       341      water              164  ...
# 3981          660        HOH       342      water              165  ...
# 3982          661        HOH       343      water              166  ...
#
#      molecule.id molecule.type entity.index  entity.name entity.id  \
# 0            NaN           NaN            0          NaN       NaN
# 1            NaN           NaN            0          NaN       NaN
# 2            NaN           NaN            0          NaN       NaN
# 3            NaN           NaN            0          NaN       NaN
# 4            NaN           NaN            0          NaN       NaN
# ...          ...           ...          ...          ...       ...
# 3978         NaN           NaN            0          NaN       NaN
# 3979         NaN           NaN            0          NaN       NaN
# 3980         NaN           NaN            0          NaN       NaN
# 3981         NaN           NaN            0          NaN       NaN
# 3982         NaN           NaN            0          NaN       NaN
#
#      entity.type bioassembly.index  bioassembly.name bioassembly.id  \
# 0            NaN                 0               NaN            NaN
# 1            NaN                 0               NaN            NaN
# 2            NaN                 0               NaN            NaN
# 3            NaN                 0               NaN            NaN
# 4            NaN                 0               NaN            NaN
# ...          ...               ...               ...            ...
# 3978         NaN                 0               NaN            NaN
# 3979         NaN                 0               NaN            NaN
# 3980         NaN                 0               NaN            NaN
# 3981         NaN                 0               NaN            NaN
# 3982         NaN                 0               NaN            NaN
#
#      bioassembly.type
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 3978              NaN
# 3979              NaN
# 3980              NaN
# 3981              NaN
# 3982              NaN
#
# [3983 rows x 29 columns]
