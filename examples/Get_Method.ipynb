# %%
from mendeleev import element

# %%
N = element('N')

# %%
help(N.electronegativity)
# Out:
# Help on method electronegativity in module mendeleev.tables:
#
# electronegativity(scale='pauling', charge=0) method of mendeleev.tables.Element instance
#     Calculate the electronegativity using one of the methods
#
#     Args:
#       scale : str
#        Name of the electronegativity scale, one of
#
#        - `allen`
#        - `allred-rochow`
#        - `cottrell-sutton`
#        - `gordy`
#        - `li-xue`
#        - `martynov-batsanov`
#        - `mulliken`
#        - `nagle`
#        - `pauling`
#        - `sanderson`
