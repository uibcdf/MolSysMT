# %%
# %load_ext autoreload
# %autoreload 2

# %%
import molmodmt as m3t
# Out:
# /home/diego/Myopt/miniconda3/envs/UIBCDF_lab_dev/lib/python3.7/site-packages/yank/experiment.py:1170: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   """)
# _ColormakerRegistry()

# %%
molecular_model = m3t.convert('1sux.pdb', selection='protein', to_form='molmodmt.MolMod')

# %% [markdown]
# ### Electronegatividad

# %% [markdown]
# La electronegatividad de una lista de átomos puede ser obtenida según distintas escalas: "allen", "allred-rochow", "cottrell-sutton", "gosh", "gordy", "li-xiu", "pauling",

# %%
en = m3t.get_atomic_electronegativity(molecular_model, scale='gosh', selection='all')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-57bcf602486c> in <module>
# ----> 1 en = m3t.get_atomic_electronegativity(molecular_model, scale='gosh', selection='all')
#
# ~/Projects/MolModMT/molmodmt/atomic_properties.py in get_atomic_electronegativity(item, scale, selection, syntaxis, engine)
#      20         for element_symbol in unique_elements:
#      21             element = _element(element_symbol)
# ---> 22             en_elements[element_symbol] = element.electronegativity(scale)
#      23         for element_symbol in selection_elements:
#      24             en_selection.append(en_elements[element_symbol])
#
# ~/Myopt/miniconda3/envs/UIBCDF_lab_dev/lib/python3.7/site-packages/mendeleev/tables.py in electronegativity(self, scale, charge)
#     554             return self.calc_en_sanderson()
#     555         else:
# ...

# %%
print(en)
# Out:
# [18.13, 15.05, 15.05, 21.36, 15.05, 18.13, 15.05, 15.05, 21.36, 15.05, 21.36, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 15.05, 15.05, 18.13, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 15.05, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 15.05, 21.36, 18.13, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 15.05, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 15.05, 15.05, 18.13, 15.05, 15.05, 21.36, 15.05, 18.13, 15.05, 15.05, 21.36, 15.05, 18.13, 15.05, 15.05, 21.36, 15.05, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 21.36, 18.13, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 15.05, 15.05, 18.13, 15.05, 15.05, 15.05, 15.05, 15.05, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 15.05, 15.05, 18.13, 18.13, 15.05, 15.05, 21.36, 15.05, 15.31, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 21.36, 18.13, 18.13, 15.05, 15.05, 21.36, 18.13, 15.05, 15.05, 21.36, 15.05, 21.36, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 15.05, 21.36, 21.36, 18.13, 15.05, 15.05, 21.36, 15.05, 21.36, 18.13, 15.05, 15.05, 21.36, 15.05, 15.05, 15.
# ...
